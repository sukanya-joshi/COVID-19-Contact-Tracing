# %% [markdown]
# # **CTM, NMF + Coherence Scores (LDA,CTM,NMF) on COVID** **Data**

# %% [markdown]
# # Installing Contextualized Topic Models
#
# First, we install the contextualized topic model library

# %%
# %%capture
# !pip install contextualized-topic-models==2.2.0

# %% [markdown]
# # Data
#
# We are going to need some data. You should upload a file with one document per line. We assume you haven't run any preprocessing script.
#
# However, if you want to first test the model without uploading your data, you can simply use the test file I'm putting here

# %% [markdown]
# # Importing what we need

# %%
import pandas as pd

# %%
from contextualized_topic_models.utils.data_preparation import TopicModelDataPreparation
from contextualized_topic_models.utils.preprocessing import WhiteSpacePreprocessing
import nltk
from contextualized_topic_models.models.ctm import CombinedTM

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# Why do we use the **preprocessed text** here? We need text without punctuation to build the bag of word. Also, we might want only to have the most frequent words inside the BoW. Too many words might not help.

# %% [markdown]
# We don't discard the non-preprocessed texts, because we are going to use them as input for obtaining the contextualized document representations.
#
# Let's pass our files with preprocess and unpreprocessed data to our `TopicModelDataPreparation` object. This object takes care of creating the bag of words for you and of obtaining the contextualized BERT representations of documents. This operation allows us to create our training dataset.
#
# Note: Here we use the contextualized model "distiluse-base-multilingual-cased", because we need a multilingual model for performing cross-lingual predictions later.

# %% [markdown]
# ## Training our CTM
#
# Finally, we can fit our new topic model. We will ask the model to find 25 topics in our collection (n_component parameter of the CTM object).

# %% [markdown]
# # Topics
#
# After training, now it is the time to look at our topics: we can use the
#
# ```
# get_topic_lists
# ```
#
# function to get the topics. It also accepts a parameter that allows you to select how many words you want to see for each topic.
#
# If you look at the topics, you will see that they all make sense and are representative of a collection of documents that comes from Wikipedia (general knowledge). Notice that the topics are in English, because we trained the model on English documents.

# %%
data = pd.read_csv('sukanya_final_1gram.csv')

# %%
data = data['feat']

# %%
data
# Out:
# 0               work
# 1                not
# 2            deinsed
# 3              again
# 4         vaccinated
#              ...
# 180528            my
# 180529         these
# 180530         south
# 180531      impaired
# 180532           who
# Name: feat, Length: 180533, dtype: object

# %%
data = data.reset_index(drop = True)

# %%
overall_data = []
for i in range(len(data)):
    data[i] = str(data[i])
    overall_data.append(data[i])

# %%
len(overall_data)
# Out:
# 180533

# %%
stopwords = ['to','and','i','.','app','the','?','this','it',',']
documents = [i for i in overall_data if i not in stopwords]

# %%
nltk.download('stopwords')
sp = WhiteSpacePreprocessing(documents, stopwords_language='english')
preprocessed_documents, unpreprocessed_corpus, vocab = sp.preprocess()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
preprocessed_documents[:10]
# Out:
# ['work',
#  'vaccinated',
#  'problem',
#  'installed',
#  'working',
#  'worked',
#  'wish',
#  'know',
#  'kept',
#  'currently']

# %%
tp = TopicModelDataPreparation("paraphrase-distilroberta-base-v1")

training_dataset = tp.fit(text_for_contextual=unpreprocessed_corpus, text_for_bow=preprocessed_documents)
# Out:
# Downloading:   0%|          | 0.00/391 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.74k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/718 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/122 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/229 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/329M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.35k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Batches:   0%|          | 0/395 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
tp.vocab[:10]
# Out:
# ['ability',
#  'able',
#  'absolute',
#  'absolutely',
#  'accept',
#  'acceptable',
#  'access',
#  'according',
#  'account',
#  'accuracy']

# %%
ctm = CombinedTM(bow_size=len(tp.vocab), contextual_size=768, n_components=25, num_epochs=10)
ctm.fit(training_dataset) # run the model
# Out:
# Epoch: [10/10]	 Seen Samples: [789690/789690]	Train Loss: 16.50780354054083	Time: 0:00:37.793082: : 10it [06:15, 37.58s/it]

# %%
ctm.bow_size
# Out:
# 2000

# %%
#all words in each topic
all_ctm = ctm.get_topic_lists(ctm.bow_size)
all_ctm
# Out:
# [['use',
#   'get',
#   'time',
#   'easy',
#   'us',
#   'way',
#   'think',
#   'useful',
#   'thing',
#   'one',
#   'wrong',
#   'things',
#   'everything',
#   'put',
#   'working',
#   'give',
#   'idea',
#   'people',
#   'take',
#   'go',
#   'tested',
#   'contact',
#   'results',
#   'test',
#   'never',
#   'positive',
#   'would',
#   'location',
#   'bad',
#   'installed',
#   'since',
#   'covid',
#   'download',
#   'safe',
#   'phone',
#   'like',
#   'google',
#   'still',
#   'alert',
#   'someone',
#   'bluetooth',
#   'even',
#   'ways',
#   'keep',
#   'work',
#   'need',
#   'really',
#   'see',
#   'day',
#   'install',
#   'says',
#   'also',
#   'help',
#   'exposed',
#   'tracking',
#   'useless',
#   'good',
#   'virus',
#   'exposure',
#   'tracing',
#   'great',
#   'works',
#   'notifications',
#   'downloaded',
#   'privacy',
#   'notification',
#   'android',
#   'health',
#   'well',
#   'thank',
#   'update',
#   'back',
#   'know',
#   'want',
#   'please',
#   'months',
#   'data',
#   'everyone',
#   'state',
#   'information',
#   'info',
#   'job',
#   'days',
#   'battery',
#   'could',
#   'others',
#   'code',
#   'without',
#   'needs',
#   'nice',
#   'given',
#   'stop',
#   'apple',
#   'turn',
#   'newline',
#   'getting',
#   'report',
#   'helpful',
#   'anyone',
#   'using',
#   'maybe',
#   'show',
#   'home',
#   'ask',
#   'better',
#   'hope',
#   'pretty',
#   'nothing',
#   'error',
#   'part',
#   'notified',
#   'first',
#   'keeps',
#   'simple',
#   'sure',
#   'point',
#   'check',
#   'much',
#   'many',
#   'seems',
#   'find',
#   'got',
#   'apps',
#   'anything',
#   'requires',
#   'call',
#   'told',
#   'live',
#   'able',
#   'notify',
#   'far',
#   'takes',
#   'longer',
#   'order',
#   'actually',
#   'track',
#   'control',
#   'fact',
#   'love',
#   'aside',
#   'enough',
#   'add',
#   'worked',
#   'let',
#   'enter',
#   'cannot',
#   'something',
#   'two',
#   'accurate',
#   'life',
#   'problem',
#   'security',
#   'least',
#   'government',
#   'allow',
#   'try',
#   'mask',
#   'permission',
#   'already',
#   'awesome',
#   'another',
#   'finally',
#   'option',
#   'may',
#   'run',
#   'numbers',
#   'every',
#   'updated',
#   'might',
#   'guess',
#   'john',
#   'said',
#   'testing',
#   'infected',
#   'past',
#   'come',
#   'clearly',
#   'times',
#   'yet',
#   'medical',
#   'proximity',
#   'samsung',
#   'used',
#   'secure',
#   'probably',
#   'risk',
#   'review',
#   'trust',
#   'locations',
#   'phones',
#   'screen',
#   'new',
#   'received',
#   'inform',
#   'three',
#   'number',
#   'important',
#   'running',
#   'make',
#   'wifi',
#   'waste',
#   'completely',
#   'stored',
#   'pin',
#   'tried',
#   'last',
#   'mind',
#   'available',
#   'wish',
#   'developer',
#   'tell',
#   'high',
#   'hour',
#   'displayed',
#   'uninstalled',
#   'practice',
#   'feel',
#   'unable',
#   'around',
#   'fix',
#   'right',
#   'shows',
#   'next',
#   'via',
#   'remind',
#   'matter',
#   'intentions',
#   'street',
#   'trying',
#   'situation',
#   'going',
#   'integrated',
#   'cant',
#   'page',
#   'person',
#   'share',
#   'red',
#   'took',
#   'lot',
#   'ensure',
#   'spread',
#   'slow',
#   'virginia',
#   'fair',
#   'taking',
#   'maintaining',
#   'settings',
#   'checked',
#   'heck',
#   'thanks',
#   'indicator',
#   'choice',
#   'stops',
#   'today',
#   'went',
#   'quicker',
#   'begin',
#   'needed',
#   'result',
#   'dont',
#   'pain',
#   'shared',
#   'staff',
#   'possibly',
#   'send',
#   'open',
#   'immune',
#   'schools',
#   'adoption',
#   'whole',
#   'user',
#   'tooth',
#   'iphone',
#   'questions',
#   'leaders',
#   'gps',
#   'green',
#   'wheel',
#   'ineffective',
#   'saves',
#   'tool',
#   'miss',
#   'trigger',
#   'sd',
#   'agency',
#   'frustrated',
#   'hopeful',
#   'consistent',
#   'reported',
#   'verification',
#   'confidence',
#   'response',
#   'participating',
#   'annoyance',
#   'however',
#   'load',
#   'set',
#   'apart',
#   'ble',
#   'loads',
#   'paranoid',
#   'addresses',
#   'warned',
#   'ever',
#   'supposed',
#   'scare',
#   'governor',
#   'separate',
#   'serious',
#   'likely',
#   'access',
#   'outbreaks',
#   'ago',
#   'possible',
#   'stay',
#   'frustrating',
#   'excellent',
#   'county',
#   'wake',
#   'border',
#   'roll',
#   'pass',
#   'july',
#   'power',
#   'little',
#   'knows',
#   'walked',
#   'charged',
#   'reality',
#   'log',
#   'steps',
#   'typical',
#   'hold',
#   'choose',
#   'implemented',
#   'place',
#   'screenshot',
#   'decision',
#   'lies',
#   'near',
#   'centers',
#   'save',
#   'link',
#   'robert',
#   'route',
#   'mainly',
#   'though',
#   'start',
#   'light',
#   'change',
#   'joke',
#   'responding',
#   'symptoms',
#   'quick',
#   'utah',
#   'mass',
#   'expected',
#   'truly',
#   'moto',
#   'sketchy',
#   'blind',
#   'technology',
#   'tv',
#   'mile',
#   'wa',
#   'plague',
#   'spy',
#   'respect',
#   'thru',
#   'statistics',
#   'cough',
#   'half',
#   'circle',
#   'uses',
#   'instantly',
#   'talking',
#   'intuitive',
#   'rather',
#   'else',
#   'cleared',
#   'believe',
#   'constantly',
#   'claiming',
#   'isolate',
#   'runs',
#   'exposures',
#   'fine',
#   'informative',
#   'points',
#   'system',
#   'nightmare',
#   'came',
#   'horrible',
#   'buena',
#   'visited',
#   'vdh',
#   'text',
#   'economy',
#   'stars',
#   'confirmation',
#   'care',
#   'millions',
#   'pandemic',
#   'draining',
#   'yorkers',
#   'extremely',
#   'written',
#   'weeks',
#   'provider',
#   'ready',
#   'unfortunate',
#   'pocket',
#   'difference',
#   'consistently',
#   'inactive',
#   'tracker',
#   'gov',
#   'flawed',
#   'folks',
#   'winter',
#   'crush',
#   'loss',
#   'happens',
#   'lie',
#   'date',
#   'pray',
#   'thus',
#   'services',
#   'started',
#   'recently',
#   'thousands',
#   'concept',
#   'birth',
#   'promoting',
#   'required',
#   'alot',
#   'families',
#   'less',
#   'parents',
#   'outside',
#   'bug',
#   'max',
#   'map',
#   'spyware',
#   'issues',
#   'emergency',
#   'parking',
#   'view',
#   'attention',
#   'collected',
#   'advised',
#   'cool',
#   'detected',
#   'interview',
#   'hung',
#   'truth',
#   'freedom',
#   'department',
#   'interstate',
#   'covidwise',
#   'created',
#   'best',
#   'jersey',
#   'massive',
#   'freedoms',
#   'recorded',
#   'bogus',
#   'checks',
#   'function',
#   'locked',
#   'terrible',
#   'se',
#   'satisfied',
#   'records',
#   'protection',
#   'play',
#   'exactly',
#   'mdh',
#   'online',
#   'entry',
#   'strangers',
#   'saying',
#   'resident',
#   'goes',
#   'misleading',
#   'racial',
#   'nj',
#   'killed',
#   'smooth',
#   'facility',
#   'anonymously',
#   'considering',
#   'dog',
#   'enable',
#   'spam',
#   'freezes',
#   'sensing',
#   'dec',
#   'confusing',
#   'section',
#   'keys',
#   'dozens',
#   'guys',
#   'met',
#   'offer',
#   'addressed',
#   'website',
#   'feedback',
#   'corrected',
#   'paranoia',
#   'meant',
#   'looks',
#   'que',
#   'lacks',
#   'ids',
#   'man',
#   'asking',
#   'interested',
#   'employee',
#   'died',
#   'encouraging',
#   'god',
#   'danger',
#   'users',
#   'weekend',
#   'monday',
#   'addition',
#   'explained',
#   'click',
#   'edit',
#   'charging',
#   'emailed',
#   'talked',
#   'md',
#   'deleting',
#   'park',
#   'federal',
#   'explain',
#   'sitting',
#   'properly',
#   'understanding',
#   'suddenly',
#   'minutes',
#   'solid',
#   'fighting',
#   'writing',
#   'magic',
#   'indicate',
#   'spending',
#   'die',
#   'exposing',
#   'turned',
#   'model',
#   'relevant',
#   'sits',
#   'forgot',
#   'regardless',
#   'executed',
#   'basically',
#   'hours',
#   'companies',
#   'fall',
#   'lives',
#   'extra',
#   'biggest',
#   'large',
#   'site',
#   'blessing',
#   'copy',
#   'america',
#   'makes',
#   'four',
#   'allergies',
#   'adds',
#   'hospitals',
#   'registration',
#   'portion',
#   'unacceptable',
#   'claims',
#   'hundreds',
#   'youtube',
#   'worried',
#   'includes',
#   'found',
#   'explains',
#   'write',
#   'professional',
#   'quickly',
#   'period',
#   'jump',
#   'facebook',
#   'seconds',
#   'spend',
#   'incredible',
#   'acceptable',
#   'importance',
#   'step',
#   'ur',
#   'actively',
#   'taste',
#   'downloading',
#   'losing',
#   'redo',
#   'mb',
#   'disappointing',
#   'sick',
#   'combat',
#   'supporting',
#   'race',
#   'buggy',
#   'crisis',
#   'eventually',
#   'university',
#   'impressed',
#   'happened',
#   'initiative',
#   'er',
#   'operating',
#   'texted',
#   'comment',
#   'birthdate',
#   'filled',
#   'similar',
#   'bottom',
#   'poorly',
#   'spins',
#   'negative',
#   'directions',
#   'survive',
#   'clicking',
#   'voluntarily',
#   'helps',
#   'promoted',
#   'head',
#   'delivery',
#   'concerned',
#   'tablet',
#   'benefits',
#   'island',
#   'customer',
#   'movements',
#   'errors',
#   'groups',
#   'traveled',
#   'form',
#   'automated',
#   'rarely',
#   'wonderful',
#   'drain',
#   'hate',
#   'aid',
#   'caught',
#   'complaining',
#   'general',
#   'glad',
#   'election',
#   'complaints',
#   'dying',
#   'correctly',
#   'assessment',
#   'gave',
#   'business',
#   'weak',
#   'failure',
#   'virtually',
#   'neighbor',
#   'brought',
#   'field',
#   'idiots',
#   'straightforward',
#   'finish',
#   'annoying',
#   'effectively',
#   'literally',
#   'gets',
#   'framework',
#   'appointment',
#   'tries',
#   'suggestion',
#   'unique',
#   'ideal',
#   'words',
#   'somebody',
#   'became',
#   'spinning',
#   'manual',
#   'encountered',
#   'prior',
#   'nd',
#   'somewhere',
#   'rhode',
#   'sending',
#   'occasions',
#   'understand',
#   'drains',
#   'solve',
#   'initially',
#   'comfortable',
#   'driver',
#   'service',
#   'target',
#   'account',
#   'ridiculous',
#   'busy',
#   'discovered',
#   'delete',
#   'shot',
#   'wide',
#   'didnt',
#   'soon',
#   'delay',
#   'happening',
#   'spoke',
#   'nonsense',
#   'indication',
#   'apparently',
#   'friday',
#   'hi',
#   'advise',
#   'size',
#   'permanently',
#   'later',
#   'cost',
#   'spouse',
#   'faster',
#   'american',
#   'constant',
#   'outbreak',
#   'compared',
#   'language',
#   'long',
#   'receive',
#   'becomes',
#   'hog',
#   'huge',
#   'requirements',
#   'tab',
#   'leave',
#   'driving',
#   'display',
#   'survival',
#   'repeatedly',
#   'china',
#   'month',
#   'honestly',
#   'vs',
#   'looked',
#   'interactions',
#   'complicated',
#   'trouble',
#   'late',
#   'honest',
#   'attempt',
#   'walking',
#   'input',
#   'incorrect',
#   'collect',
#   'slider',
#   'beat',
#   'question',
#   'pop',
#   'reviews',
#   'affected',
#   'currently',
#   'minimal',
#   'ill',
#   'october',
#   'wasting',
#   'pay',
#   'moved',
#   'ri',
#   'major',
#   'space',
#   'seeing',
#   'entered',
#   'saw',
#   'personally',
#   'relying',
#   'alarm',
#   'informing',
#   'convenient',
#   'stuck',
#   'pixel',
#   'depend',
#   'twice',
#   'unlikely',
#   'receiving',
#   'zip',
#   'breakdown',
#   'slowing',
#   'guy',
#   'patients',
#   'upload',
#   'week',
#   'walks',
#   'la',
#   'opened',
#   'living',
#   'counter',
#   'within',
#   'neighborhood',
#   'recieved',
#   'alabama',
#   'national',
#   'comprehensive',
#   'california',
#   'wasted',
#   'newest',
#   'circles',
#   'brother',
#   'completed',
#   'afternoon',
#   'interface',
#   'recommended',
#   'reading',
#   'suspect',
#   'wonder',
#   'sake',
#   'collection',
#   'problems',
#   'steal',
#   'alerting',
#   'unusable',
#   'clever',
#   'straight',
#   'initial',
#   'issue',
#   'killing',
#   'bit',
#   'minnesota',
#   'releasing',
#   'percentage',
#   'internet',
#   'collecting',
#   'nov',
#   'answered',
#   'focus',
#   'key',
#   'loop',
#   'face',
#   'doctors',
#   'kill',
#   'earlier',
#   'everyday',
#   'vaccine',
#   'participate',
#   'sell',
#   'quarantined',
#   'morning',
#   'gives',
#   'serves',
#   'confirmed',
#   'ap',
#   'notes',
#   'defeats',
#   'specifically',
#   'highest',
#   'shopping',
#   'country',
#   'elsewhere',
#   'admit',
#   'double',
#   'goal',
#   'family',
#   'spots',
#   'exists',
#   'totally',
#   'hacked',
#   'turning',
#   'instructed',
#   'age',
#   'say',
#   'letting',
#   'trace',
#   'son',
#   'threat',
#   'design',
#   'ct',
#   'onto',
#   'announced',
#   'taxpayer',
#   'sanitizer',
#   'complaint',
#   'fight',
#   'realize',
#   'yesterday',
#   'drive',
#   'join',
#   'scary',
#   'progress',
#   'causes',
#   'march',
#   'direct',
#   'nys',
#   'bc',
#   'unconstitutional',
#   'uninstall',
#   'assuming',
#   'incredibly',
#   'residents',
#   'regular',
#   'signal',
#   'hangs',
#   'details',
#   'room',
#   'offered',
#   'bed',
#   'wrote',
#   'hopefully',
#   'loaded',
#   'immediately',
#   'requiring',
#   'seemingly',
#   'besides',
#   'science',
#   'utilize',
#   'distancing',
#   'box',
#   'disabled',
#   'unfortunately',
#   'town',
#   'restarted',
#   'unobtrusive',
#   'couple',
#   'hell',
#   'engineer',
#   'stopped',
#   'hundred',
#   'leaves',
#   'neither',
#   'lost',
#   'continues',
#   'bunch',
#   'appt',
#   'contacts',
#   'case',
#   'places',
#   'amazing',
#   'unnecessary',
#   'higher',
#   'company',
#   'wow',
#   'note',
#   'refuses',
#   'feature',
#   'screw',
#   'corona',
#   'count',
#   'sadly',
#   'september',
#   'travel',
#   'az',
#   'dept',
#   'laws',
#   'elderly',
#   'manually',
#   'quarantining',
#   'anywhere',
#   'existed',
#   'granted',
#   'los',
#   'absolutely',
#   'paid',
#   'vital',
#   'deleted',
#   'drop',
#   'followed',
#   'allowed',
#   'effort',
#   'effectiveness',
#   'lead',
#   'searching',
#   'guidelines',
#   'party',
#   'scanning',
#   'requests',
#   'junk',
#   'purchase',
#   'retail',
#   'waited',
#   'sooner',
#   'creates',
#   'expect',
#   'across',
#   'throat',
#   'close',
#   'experienced',
#   'research',
#   'highly',
#   'pro',
#   'sometimes',
#   'diagnosis',
#   'flaw',
#   'removing',
#   'evening',
#   'store',
#   'experiencing',
#   'recommendation',
#   'apartment',
#   'mn',
#   ...],
#  ['even',
#   'google',
#   'completely',
#   'far',
#   'minutes',
#   'start',
#   'finally',
#   'possible',
#   'mask',
#   'already',
#   'gets',
#   'county',
#   'glad',
#   'android',
#   'numbers',
#   'enter',
#   'government',
#   'least',
#   'developer',
#   'wifi',
#   'recommend',
#   'infected',
#   'takes',
#   'security',
#   'definitely',
#   'required',
#   'run',
#   'samsung',
#   'shows',
#   'absolutely',
#   'secure',
#   'deleting',
#   'fight',
#   'drains',
#   'tracker',
#   'totally',
#   'ready',
#   'running',
#   'tracer',
#   'governor',
#   'quickly',
#   'likely',
#   'ny',
#   'trace',
#   'reports',
#   'reported',
#   'updating',
#   'currently',
#   'worth',
#   'knows',
#   'invasion',
#   'locked',
#   'media',
#   'confirmed',
#   'whether',
#   'entered',
#   'kills',
#   'dept',
#   'smart',
#   'safer',
#   'requires',
#   'control',
#   'impossible',
#   'leaving',
#   'means',
#   'runs',
#   'seconds',
#   'probably',
#   'taken',
#   'minute',
#   'perhaps',
#   'showed',
#   'goes',
#   'beyond',
#   'finish',
#   'areas',
#   'maybe',
#   'positives',
#   'doesnt',
#   'internet',
#   'general',
#   'zero',
#   'post',
#   'obviously',
#   'avoid',
#   'tokens',
#   'countries',
#   'freezes',
#   'infection',
#   'drained',
#   'certain',
#   'draining',
#   'faster',
#   'source',
#   'codes',
#   'entering',
#   'afraid',
#   'adopt',
#   'fear',
#   'de',
#   'worse',
#   'mobile',
#   'installs',
#   'willing',
#   'cdc',
#   'identify',
#   'vulnerable',
#   'recommended',
#   'software',
#   'california',
#   'gone',
#   'certainly',
#   'assume',
#   'thats',
#   'protects',
#   'knowing',
#   'although',
#   'navigate',
#   'attempts',
#   'count',
#   'purchase',
#   'ten',
#   'computer',
#   'beginning',
#   'nearly',
#   'outbreaks',
#   'connected',
#   'widespread',
#   'didnt',
#   'password',
#   'logged',
#   'muy',
#   'digit',
#   'previously',
#   'appears',
#   'advertised',
#   'killing',
#   'havent',
#   'indicates',
#   'physical',
#   'sad',
#   'anymore',
#   'race',
#   'tech',
#   'million',
#   'connection',
#   'hot',
#   'restarted',
#   'biggest',
#   'washington',
#   'saves',
#   'manually',
#   'normally',
#   'november',
#   'infect',
#   'wyoming',
#   'cleared',
#   'sends',
#   'proven',
#   'pops',
#   'man',
#   'basic',
#   'encounters',
#   'federal',
#   'defeats',
#   'potentially',
#   'quarantined',
#   'described',
#   'prompt',
#   'trips',
#   'id',
#   'possibly',
#   'till',
#   'saving',
#   'attempting',
#   'suggest',
#   'whats',
#   'tired',
#   'white',
#   'chances',
#   'lacks',
#   'promoted',
#   'protecting',
#   'idiots',
#   'moto',
#   'therefore',
#   'main',
#   'needing',
#   'previous',
#   'begin',
#   'measures',
#   'president',
#   'engineer',
#   'nightmare',
#   'dollars',
#   'met',
#   'third',
#   'earlier',
#   'reinstalling',
#   'dev',
#   'diary',
#   'zip',
#   'hide',
#   'weekend',
#   'pending',
#   'popped',
#   'political',
#   'allows',
#   'easily',
#   'window',
#   'web',
#   'usually',
#   'comfortable',
#   'disable',
#   'florida',
#   'easiest',
#   'opt',
#   'scare',
#   'smartphone',
#   'quarantining',
#   'requiring',
#   'instantly',
#   'opening',
#   'encountered',
#   'might',
#   'doubt',
#   'trump',
#   'slider',
#   'devs',
#   'decent',
#   'protected',
#   'counties',
#   'automated',
#   'disease',
#   'highest',
#   'taste',
#   'trusted',
#   'inslee',
#   'monitor',
#   'manner',
#   'fault',
#   'ads',
#   'stored',
#   'unlikely',
#   'drop',
#   'login',
#   'spins',
#   'ids',
#   'drove',
#   'included',
#   'dob',
#   'thus',
#   'releasing',
#   'supported',
#   'dog',
#   'walked',
#   'plan',
#   'successful',
#   'connections',
#   'effectiveness',
#   'nys',
#   'emailed',
#   'usual',
#   'graphs',
#   'rolled',
#   'claims',
#   'april',
#   'optional',
#   'onto',
#   'maintaining',
#   'yorkers',
#   'slowing',
#   'ideal',
#   'launched',
#   'registered',
#   'compatible',
#   'guy',
#   'prevent',
#   'overnight',
#   'locks',
#   'hopes',
#   'brought',
#   'barely',
#   'improvements',
#   'walks',
#   'allowing',
#   'office',
#   'specifically',
#   'developing',
#   'retail',
#   'informing',
#   'kinda',
#   'spinning',
#   'eats',
#   'existed',
#   'missing',
#   'contain',
#   'dakota',
#   'doctor',
#   'leaves',
#   'network',
#   'causing',
#   'virtually',
#   'mdh',
#   'caused',
#   'allowed',
#   'ahead',
#   'unique',
#   'door',
#   'freeze',
#   'benefits',
#   'sooner',
#   'interactions',
#   'corrected',
#   'survive',
#   'hippa',
#   'sanitizer',
#   'wireless',
#   'integrated',
#   'green',
#   'wasting',
#   'west',
#   'middle',
#   'gonna',
#   'pm',
#   'tools',
#   'wasted',
#   'showing',
#   'scanning',
#   'keys',
#   'becomes',
#   'rapid',
#   'monitoring',
#   'communities',
#   'spouse',
#   'forgot',
#   'youtube',
#   'advertising',
#   'kudos',
#   'thinks',
#   'claiming',
#   'movements',
#   'expect',
#   'killed',
#   'minor',
#   'tracers',
#   'screenshot',
#   'hacked',
#   'started',
#   'average',
#   'leadership',
#   'return',
#   'apparently',
#   'beta',
#   'throat',
#   'meant',
#   'generate',
#   'hacking',
#   'isnt',
#   'besides',
#   'buggy',
#   'official',
#   'mail',
#   'apparent',
#   'conditions',
#   'centers',
#   'considered',
#   'answered',
#   'controlling',
#   'indication',
#   'wash',
#   'proceed',
#   'recommendation',
#   'miles',
#   'body',
#   'wont',
#   'fake',
#   'min',
#   'appear',
#   'minimal',
#   'verified',
#   'potential',
#   'evening',
#   'half',
#   'businesses',
#   'sketchy',
#   'immediate',
#   'border',
#   'appt',
#   'bc',
#   'assuming',
#   'brilliant',
#   'sd',
#   'personally',
#   'cvs',
#   'recieved',
#   'remain',
#   'inside',
#   'sources',
#   'exact',
#   'admit',
#   'election',
#   'spending',
#   'depends',
#   'whatever',
#   'mb',
#   'officials',
#   'spoke',
#   'usa',
#   'weird',
#   'delay',
#   'searching',
#   'light',
#   'practice',
#   'members',
#   'hawaii',
#   'essentially',
#   'straightforward',
#   'nonsense',
#   'freedom',
#   'opinion',
#   'target',
#   'stores',
#   'sleeping',
#   'participation',
#   'exists',
#   'monday',
#   'crisis',
#   'mostly',
#   'en',
#   'executed',
#   'hung',
#   'detected',
#   'afternoon',
#   'changing',
#   'guidelines',
#   'feet',
#   'spend',
#   'pleasant',
#   'pull',
#   'road',
#   'ing',
#   'flawed',
#   'clever',
#   'ran',
#   'survival',
#   'select',
#   'interview',
#   'announced',
#   'risks',
#   'freedoms',
#   'wolf',
#   'prompts',
#   'restart',
#   'protection',
#   'tablet',
#   'affected',
#   'identifiable',
#   'citizen',
#   'trigger',
#   'temporary',
#   'er',
#   'hundreds',
#   'alabama',
#   'suggestions',
#   'consistently',
#   'attempted',
#   'fan',
#   'roommate',
#   'positivity',
#   'virginians',
#   'removing',
#   'weak',
#   'progress',
#   'research',
#   'colorado',
#   'requests',
#   'addresses',
#   'az',
#   'explained',
#   'frequently',
#   'assistance',
#   'somehow',
#   'paranoia',
#   'downloads',
#   'deserve',
#   'nov',
#   'errands',
#   'sensing',
#   'agency',
#   'strangers',
#   'favor',
#   'employer',
#   'dying',
#   'functioning',
#   'screw',
#   'hold',
#   'indicator',
#   'virginian',
#   'millions',
#   'knew',
#   'blessed',
#   'solve',
#   'hangs',
#   'appreciated',
#   'success',
#   'moved',
#   'promoting',
#   'percent',
#   'dozens',
#   'dashboard',
#   'automatically',
#   'fair',
#   'emails',
#   'talks',
#   'percentage',
#   'quicker',
#   'dates',
#   'september',
#   'stated',
#   'participating',
#   'aid',
#   'sake',
#   'nose',
#   'relying',
#   'corona',
#   'noted',
#   'bother',
#   'model',
#   'rates',
#   'addressed',
#   'notices',
#   'operating',
#   'movement',
#   'framework',
#   'groceries',
#   'circles',
#   'faith',
#   'facebook',
#   'feels',
#   'suddenly',
#   'lucky',
#   'lists',
#   'idk',
#   'food',
#   'invasive',
#   'neighbors',
#   'island',
#   'shown',
#   'vs',
#   'iphones',
#   'suggested',
#   'expected',
#   'blessing',
#   'sits',
#   'identity',
#   'diagnosed',
#   'tries',
#   'confirmation',
#   'suggestion',
#   'families',
#   'saved',
#   'unconstitutional',
#   'excelente',
#   'sit',
#   'benefit',
#   'attempt',
#   'companies',
#   'un',
#   'depend',
#   'waited',
#   'caught',
#   'friday',
#   'fighting',
#   'resident',
#   'suspect',
#   'nationwide',
#   'interstate',
#   'hi',
#   'satisfied',
#   'enabling',
#   'max',
#   'scroll',
#   'launch',
#   'cellphone',
#   'convinced',
#   'conspiracy',
#   'unknown',
#   'residents',
#   'adding',
#   'doh',
#   'roll',
#   'nation',
#   'typical',
#   'indicate',
#   'assessment',
#   'following',
#   'entirely',
#   'feb',
#   'unlike',
#   'direct',
#   'terms',
#   'shopping',
#   'american',
#   'completed',
#   'selecting',
#   'limited',
#   'redo',
#   'route',
#   'seemingly',
#   'files',
#   'retrieve',
#   'sounds',
#   'kids',
#   'beware',
#   'wisconsin',
#   'inactive',
#   'smooth',
#   'hundred',
#   'points',
#   'robert',
#   'steal',
#   'causes',
#   'frustrated',
#   'university',
#   'absolute',
#   'efforts',
#   'whatsoever',
#   'household',
#   'steps',
#   'bring',
#   'science',
#   'hopeful',
#   'breakdown',
#   'consistent',
#   'charged',
#   'initially',
#   'improve',
#   'scrolling',
#   'stick',
#   'wanting',
#   'focus',
#   'english',
#   'requirements',
#   'pocket',
#   'logs',
#   'utilize',
#   'americans',
#   'tracks',
#   'touch',
#   'liberty',
#   'doctors',
#   'texted',
#   'confirm',
#   'trip',
#   'plenty',
#   'customer',
#   'shot',
#   'reload',
#   'suppose',
#   'auto',
#   'talked',
#   'notifies',
#   'tho',
#   'category',
#   'bogus',
#   'regular',
#   'mi',
#   'dont',
#   'combat',
#   'functional',
#   'reviewers',
#   'creates',
#   'los',
#   'jump',
#   'nope',
#   'ultra',
#   'slowcovidnc',
#   'fails',
#   'taxpayer',
#   'aside',
#   'valid',
#   'comes',
#   'entire',
#   'ill',
#   'spots',
#   'lead',
#   'allergies',
#   'seemed',
#   'disappeared',
#   'advise',
#   'names',
#   'cough',
#   'become',
#   'mandatory',
#   'neighbor',
#   'approach',
#   'threat',
#   'cost',
#   'ended',
#   'picked',
#   'intentions',
#   'listed',
#   'tracked',
#   'sadly',
#   'hack',
#   'sell',
#   'july',
#   'park',
#   'schools',
#   'tap',
#   'truth',
#   'focused',
#   'rhode',
#   'warned',
#   'confused',
#   'screens',
#   'future',
#   'anonymity',
#   'alarm',
#   'special',
#   'crashes',
#   'human',
#   'facility',
#   'head',
#   'default',
#   'vaccination',
#   'paranoid',
#   'filled',
#   'recording',
#   'requested',
#   'unacceptable',
#   'driver',
#   'son',
#   'instructed',
#   'failing',
#   'outside',
#   'racial',
#   'buena',
#   'attention',
#   'notes',
#   'proud',
#   'statewide',
#   'duty',
#   'compared',
#   'includes',
#   'supporting',
#   'portion',
#   'groups',
#   'occasions',
#   'throughout',
#   'obtain',
#   'refuses',
#   'october',
#   'switch',
#   'acceptable',
#   'importance',
#   'exposing',
#   'join',
#   'size',
#   'unusable',
#   'confidence',
#   'damn',
#   'permanently',
#   'randomly',
#   'involved',
#   'signal',
#   'misleading',
#   'dark',
#   'line',
#   'ap',
#   'lying',
#   'moving',
#   'displayed',
#   'lower',
#   'dec',
#   'stating',
#   'activate',
#   'field',
#   'encourage',
#   'nevada',
#   'four',
#   'spreading',
#   'responsible',
#   'warnings',
#   'appropriate',
#   'employees',
#   'memory',
#   'lies',
#   'elsewhere',
#   'vaccines',
#   'eventually',
#   'actively',
#   'levels',
#   'counter',
#   'collection',
#   'effectively',
#   'md',
#   'encouraging',
#   'paper',
#   'loop',
#   'shut',
#   'apart',
#   'forcing',
#   'requirement',
#   'directions',
#   'mainly',
#   'match',
#   'december',
#   'saver',
#   'regarding',
#   'voluntarily',
#   'plague',
#   'records',
#   'hospitals',
#   'losing',
#   'lack',
#   'scary',
#   'yeah',
#   'reality',
#   'outbreak',
#   'eat',
#   'registration',
#   'passed',
#   'unlock',
#   'detect',
#   'relevant',
#   'increase',
#   'versions',
#   'march',
#   'region',
#   'spyware',
#   'child',
#   'implementation',
#   'tv',
#   'understanding',
#   'survey',
#   'serves',
#   'comprehensive',
#   'icon',
#   'blank',
#   'puts',
#   'decision',
#   'anonymously',
#   'crash',
#   'sending',
#   'delivery',
#   'advised',
#   'hipaa',
#   'loving',
#   'awareness',
#   'jersey',
#   'implemented',
#   'whose',
#   'hurt',
#   'collected',
#   'unfortunate',
#   'adjust',
#   'whenever',
#   'violating',
#   'hog',
#   'book',
#   'arizona',
#   'stays',
#   'circle',
#   'manual',
#   'method',
#   'critical',
#   'york',
#   'busy',
#   'repeatedly',
#   'policy',
#   'associated',
#   'immune',
#   'responding',
#   'unnecessary',
#   'years',
#   'incredible',
#   'traveled',
#   'anybody',
#   'sleep',
#   'discovered',
#   'leaders',
#   'honestly',
#   'thankfully',
#   'ensure',
#   'peoples',
#   'experiencing',
#   'pain',
#   'spy',
#   'fi',
#   'everytime',
#   'apartment',
#   'economy',
#   'birthdate',
#   'database',
#   'national',
#   'develop',
#   'initiative',
#   'effect',
#   'hear',
#   'errors',
#   'sister',
#   'alerting',
#   'kill',
#   'thousands',
#   'danger',
#   'excuse',
#   'connect',
#   'mile',
#   'realized',
#   'consent',
#   'requesting',
#   'sensitive',
#   'crush',
#   'language',
#   'died',
#   'town',
#   'sunday',
#   'winter',
#   'choice',
#   'complicated',
#   'dc',
#   'dead',
#   'pins',
#   'ble',
#   'ri',
#   'constant',
#   'ur',
#   'box',
#   'development',
#   'departments',
#   'proof',
#   'parking',
#   'relief',
#   'bottom',
#   'fall',
#   'functions',
#   'stopping',
#   'necessary',
#   'interface',
#   'reset',
#   'continues',
#   'execution',
#   'street',
#   'directly',
#   'faq',
#   'scared',
#   'wheel',
#   'john',
#   'patients',
#   'member',
#   'adds',
#   'isolate',
#   'unobtrusive',
#   'bless',
#   'mentioned',
#   'collecting',
#   'elderly',
#   'newest',
#   'activated',
#   'party',
#   'charging',
#   'pleased',
#   'story',
#   'month',
#   'determine',
#   'heck',
#   'mongering',
#   'considering',
#   'goal',
#   'interested',
#   'disappointing',
#   'six',
#   'coworkers',
#   'neighborhood',
#   'appointment',
#   'goodness',
#   'magic',
#   'upset',
#   'wrote',
#   'hoax',
#   'parents',
#   'lie',
#   'regularly',
#   'loss',
#   'spot',
#   'double',
#   'course',
#   'communicate',
#   'comments',
#   'form',
#   'emergency',
#   'helped',
#   'listen',
#   'recognize',
#   'hey',
#   'forget',
#   'spam',
#   'whoever',
#   ...],
#  ['something',
#   'new',
#   'since',
#   'actually',
#   'report',
#   'well',
#   'turn',
#   'hope',
#   'thanks',
#   'much',
#   'say',
#   'love',
#   'safe',
#   'hours',
#   'alert',
#   'checked',
#   'ago',
#   'stars',
#   'cases',
#   'family',
#   'received',
#   'today',
#   'effective',
#   'daily',
#   'stay',
#   'public',
#   'come',
#   'set',
#   'spread',
#   'long',
#   'verification',
#   'however',
#   'close',
#   'message',
#   'fast',
#   'personal',
#   'else',
#   'reviews',
#   'within',
#   'done',
#   'store',
#   'week',
#   'always',
#   'several',
#   'made',
#   'area',
#   'fine',
#   'later',
#   'telling',
#   'otherwise',
#   'either',
#   'sense',
#   'together',
#   'sent',
#   'making',
#   'different',
#   'money',
#   'button',
#   'ok',
#   'called',
#   'star',
#   'correct',
#   'away',
#   'based',
#   'yes',
#   'friends',
#   'multiple',
#   'real',
#   'appreciate',
#   'gotten',
#   'kind',
#   'hard',
#   'checking',
#   'thought',
#   'ability',
#   'year',
#   'rate',
#   'world',
#   'house',
#   'look',
#   'etc',
#   'due',
#   'complete',
#   'end',
#   'people',
#   'positive',
#   'purpose',
#   'results',
#   'experience',
#   'like',
#   'covid',
#   'aware',
#   'version',
#   'day',
#   'need',
#   'big',
#   'phone',
#   'usage',
#   'false',
#   'even',
#   'easy',
#   'timely',
#   'good',
#   'state',
#   'idea',
#   'test',
#   'days',
#   'tested',
#   'total',
#   'keep',
#   'using',
#   'feel',
#   'get',
#   'sure',
#   'still',
#   'google',
#   'would',
#   'someone',
#   'continue',
#   'never',
#   'really',
#   'used',
#   'installed',
#   'battery',
#   'use',
#   'download',
#   'exposure',
#   'better',
#   'want',
#   'times',
#   'code',
#   'around',
#   'bluetooth',
#   'know',
#   'often',
#   'cause',
#   'thank',
#   'one',
#   'track',
#   'without',
#   'right',
#   'notification',
#   'works',
#   'tracking',
#   'newline',
#   'work',
#   'option',
#   'seen',
#   'install',
#   'others',
#   'current',
#   'plus',
#   'needs',
#   'useless',
#   'downloaded',
#   'tell',
#   'overall',
#   'seems',
#   'community',
#   'go',
#   'notifications',
#   'let',
#   'way',
#   'great',
#   'got',
#   'information',
#   'virus',
#   'released',
#   'result',
#   'simple',
#   'normal',
#   'contact',
#   'location',
#   'help',
#   'far',
#   'locations',
#   'nothing',
#   'time',
#   'system',
#   'check',
#   'yet',
#   'every',
#   'turned',
#   'everyone',
#   'notified',
#   'ask',
#   'stop',
#   'see',
#   'read',
#   'says',
#   'put',
#   'government',
#   'make',
#   'apple',
#   'data',
#   'anything',
#   'common',
#   'uses',
#   'tracing',
#   'trying',
#   'care',
#   'privacy',
#   'give',
#   'finally',
#   'last',
#   'also',
#   'could',
#   'answer',
#   'take',
#   'anyone',
#   'forget',
#   'job',
#   'helpful',
#   'please',
#   'screen',
#   'info',
#   'many',
#   'problem',
#   'possible',
#   'awesome',
#   'makes',
#   'waste',
#   'try',
#   'health',
#   'back',
#   'exposed',
#   'perfect',
#   'glad',
#   'apps',
#   'another',
#   'functional',
#   'working',
#   'android',
#   'two',
#   'thinking',
#   'might',
#   'tried',
#   'available',
#   'live',
#   'slow',
#   'already',
#   'asking',
#   'anyway',
#   'number',
#   'keeps',
#   'past',
#   'open',
#   'worked',
#   'first',
#   'part',
#   'may',
#   'able',
#   'review',
#   'high',
#   'think',
#   'getting',
#   'fully',
#   'completely',
#   'ever',
#   'enable',
#   'months',
#   'person',
#   'update',
#   'requires',
#   'hospital',
#   'error',
#   'horrible',
#   'fact',
#   'accurate',
#   'running',
#   'pin',
#   'nice',
#   'cannot',
#   'hour',
#   'life',
#   'county',
#   'true',
#   'add',
#   'home',
#   'went',
#   'samsung',
#   'security',
#   'uninstalled',
#   'matter',
#   'show',
#   'point',
#   'wish',
#   'department',
#   'mask',
#   'though',
#   'enter',
#   'yeah',
#   'gps',
#   'believe',
#   'order',
#   'twice',
#   'phones',
#   'wife',
#   'enough',
#   'concept',
#   'maybe',
#   'places',
#   'virginia',
#   'testing',
#   'call',
#   'date',
#   'place',
#   'entered',
#   'minutes',
#   'questions',
#   'medical',
#   'mind',
#   'least',
#   'page',
#   'clearly',
#   'deleting',
#   'notify',
#   'lot',
#   'pretty',
#   'cant',
#   'issue',
#   'useful',
#   'came',
#   'longer',
#   'going',
#   'next',
#   'reported',
#   'downloading',
#   'guess',
#   'fix',
#   'everything',
#   'find',
#   'informative',
#   'user',
#   'joke',
#   'recent',
#   'confusing',
#   'utah',
#   'symptoms',
#   'definitely',
#   'extremely',
#   'text',
#   'told',
#   'share',
#   'service',
#   'cell',
#   'permission',
#   'gets',
#   'saying',
#   'start',
#   'quick',
#   'via',
#   'loads',
#   'warn',
#   'access',
#   'tool',
#   'fantastic',
#   'lost',
#   'settings',
#   'exposures',
#   'unless',
#   'excellent',
#   'mass',
#   'pleasant',
#   'crush',
#   'play',
#   'bug',
#   'infected',
#   'near',
#   'currently',
#   'wifi',
#   'allow',
#   'seriously',
#   'late',
#   'said',
#   'saves',
#   'stuck',
#   'alerts',
#   'difference',
#   'important',
#   'numbers',
#   'sick',
#   'issues',
#   'leaders',
#   'properly',
#   'updated',
#   'given',
#   'pain',
#   'known',
#   'leave',
#   'load',
#   'uninstall',
#   'rating',
#   'power',
#   'choice',
#   'reporting',
#   'reach',
#   'shows',
#   'contacts',
#   'required',
#   'protect',
#   'incorrect',
#   'checks',
#   'best',
#   'trust',
#   'informed',
#   'receive',
#   'deaths',
#   'saw',
#   'lie',
#   'little',
#   'instead',
#   'aside',
#   'hopefully',
#   'soon',
#   'provided',
#   'concern',
#   'stupid',
#   'happens',
#   'setup',
#   'whole',
#   'correctly',
#   'friendly',
#   'log',
#   'trigger',
#   'recommend',
#   'reality',
#   'supposed',
#   'history',
#   'took',
#   'wheel',
#   'feature',
#   'safety',
#   'allowing',
#   'us',
#   'function',
#   'interstate',
#   'actual',
#   'coronavirus',
#   'john',
#   'provider',
#   'obviously',
#   'integrated',
#   'run',
#   'changed',
#   'blind',
#   'rather',
#   'roll',
#   'month',
#   'noticed',
#   'ive',
#   'walked',
#   'period',
#   'drained',
#   'smooth',
#   'faith',
#   'pa',
#   'serious',
#   'private',
#   'alot',
#   'huge',
#   'save',
#   'possibly',
#   'especially',
#   'governor',
#   'adoption',
#   'solid',
#   'patient',
#   'scary',
#   'difficult',
#   'response',
#   'sending',
#   'executed',
#   'thing',
#   'change',
#   'written',
#   'dont',
#   'needed',
#   'found',
#   'tells',
#   'apart',
#   'users',
#   'fight',
#   'agency',
#   'states',
#   'families',
#   'local',
#   'hold',
#   'likely',
#   'tab',
#   'cool',
#   'secure',
#   'constant',
#   'seeing',
#   'consistently',
#   'surprised',
#   'designed',
#   'sorry',
#   'developer',
#   'lives',
#   'inform',
#   'major',
#   'reason',
#   'stopped',
#   'iphone',
#   'unfortunately',
#   'worthless',
#   'developed',
#   'unable',
#   'tries',
#   'border',
#   'draining',
#   'switch',
#   'masks',
#   'morning',
#   'gave',
#   'folks',
#   'entry',
#   'whatever',
#   'drain',
#   'understand',
#   'higher',
#   'proximity',
#   'town',
#   'nj',
#   'errors',
#   'unnecessary',
#   'charge',
#   'neither',
#   'rights',
#   'hell',
#   'paranoia',
#   'strangers',
#   'excited',
#   'wear',
#   'spy',
#   'doubt',
#   'indicator',
#   'happening',
#   'annoyance',
#   'kept',
#   'opened',
#   'god',
#   'pray',
#   'amazing',
#   'record',
#   'loop',
#   'fighting',
#   'impressed',
#   'sanitizer',
#   'addition',
#   'racial',
#   'talking',
#   'question',
#   'repeatedly',
#   'min',
#   'statistics',
#   'advise',
#   'minute',
#   'intuitive',
#   'charging',
#   'basically',
#   'hi',
#   'wow',
#   'annoying',
#   'frustrating',
#   'address',
#   'pocket',
#   'space',
#   'details',
#   'clear',
#   'setting',
#   'link',
#   'parents',
#   'fair',
#   'se',
#   'kids',
#   'negative',
#   'jersey',
#   'wonderful',
#   'intentions',
#   'movement',
#   'facility',
#   'im',
#   'accurately',
#   'api',
#   'tracer',
#   'relevant',
#   'quickly',
#   'confirmed',
#   'pass',
#   'regardless',
#   'click',
#   'stops',
#   'takes',
#   'york',
#   'claiming',
#   'choose',
#   'across',
#   'michigan',
#   'collect',
#   'learn',
#   'ca',
#   'satisfied',
#   'ready',
#   'pay',
#   'tv',
#   'confirm',
#   'yesterday',
#   'sd',
#   'isolate',
#   'finish',
#   'devices',
#   'verify',
#   'risk',
#   'background',
#   'target',
#   'pixel',
#   'alabama',
#   'looked',
#   'hacking',
#   'gov',
#   'voluntarily',
#   'vaccine',
#   'consistent',
#   'gives',
#   'country',
#   'control',
#   'okay',
#   'mainly',
#   'keys',
#   'turning',
#   'sitting',
#   'expected',
#   'terrible',
#   'technology',
#   'january',
#   'team',
#   'red',
#   'input',
#   'instructions',
#   'ap',
#   'interface',
#   'refuses',
#   'directions',
#   'dec',
#   'levels',
#   'explained',
#   'centers',
#   'death',
#   'ct',
#   'pop',
#   'buena',
#   'spent',
#   'course',
#   'convenient',
#   'runs',
#   'exact',
#   'informing',
#   'significant',
#   'weekend',
#   'caught',
#   'quicker',
#   'sign',
#   'services',
#   'experiencing',
#   'drains',
#   'concerns',
#   'slider',
#   'stored',
#   'implemented',
#   'reasons',
#   'suddenly',
#   'large',
#   'garbage',
#   'forcing',
#   'inaccurate',
#   'route',
#   'staff',
#   'inactive',
#   'usa',
#   'highly',
#   'max',
#   'online',
#   'lies',
#   'wide',
#   'problems',
#   'section',
#   'weekly',
#   'hundreds',
#   'rid',
#   'bed',
#   'fall',
#   'shared',
#   'charged',
#   'distance',
#   'pointless',
#   'identity',
#   'misleading',
#   'visited',
#   'double',
#   'step',
#   'tracers',
#   'separate',
#   'initially',
#   'require',
#   'application',
#   'specifically',
#   'files',
#   'nation',
#   'beat',
#   'drive',
#   'age',
#   'missing',
#   'case',
#   'china',
#   'instantly',
#   'losing',
#   'knows',
#   'circle',
#   'level',
#   'light',
#   'dozens',
#   'recently',
#   'goal',
#   'incredible',
#   'combat',
#   'considering',
#   'guys',
#   'constantly',
#   'participating',
#   'edit',
#   'birth',
#   'serves',
#   'permissions',
#   'schools',
#   'seem',
#   'support',
#   'unique',
#   'asap',
#   'que',
#   'truth',
#   'moto',
#   'knew',
#   'actively',
#   'sake',
#   'dying',
#   'america',
#   'areas',
#   'scare',
#   'words',
#   'looks',
#   'situation',
#   'extra',
#   'key',
#   'emailed',
#   'wanted',
#   'practice',
#   'robert',
#   'successful',
#   'notice',
#   'asks',
#   'showed',
#   'survival',
#   'afternoon',
#   'effort',
#   'face',
#   'met',
#   'weeks',
#   'unfortunate',
#   'driver',
#   'az',
#   'amount',
#   'closed',
#   'steal',
#   'wa',
#   'rhode',
#   'disappointed',
#   'ineffective',
#   'crazy',
#   'paid',
#   'special',
#   'groups',
#   'offer',
#   'living',
#   'distancing',
#   'hurt',
#   'adjust',
#   'count',
#   'laws',
#   'immediately',
#   'website',
#   'paranoid',
#   'whatsoever',
#   'kills',
#   'prior',
#   'display',
#   'usual',
#   'mean',
#   'frustrated',
#   'night',
#   'trips',
#   'points',
#   'dr',
#   'south',
#   'companies',
#   'lacks',
#   'displayed',
#   'fi',
#   'tracker',
#   'healthcare',
#   'importance',
#   'wonder',
#   'complicated',
#   'survive',
#   'parking',
#   'reports',
#   'clicking',
#   'respect',
#   'hopeful',
#   'interested',
#   'sister',
#   'magic',
#   'process',
#   'green',
#   'stats',
#   'outside',
#   'saver',
#   'created',
#   'july',
#   'er',
#   'initiative',
#   'loss',
#   'entirely',
#   'immune',
#   'elsewhere',
#   'feet',
#   'concerned',
#   'must',
#   'residents',
#   'faq',
#   'curve',
#   'ble',
#   'development',
#   'comment',
#   'company',
#   'list',
#   'explain',
#   'wrong',
#   'addressed',
#   'site',
#   'responding',
#   'note',
#   'social',
#   'failure',
#   'letting',
#   'addresses',
#   'general',
#   'national',
#   'flawed',
#   'stuff',
#   'framework',
#   'explains',
#   'economy',
#   'random',
#   'super',
#   'traveled',
#   'pennsylvania',
#   'winter',
#   'individuals',
#   'giving',
#   'registration',
#   'island',
#   'experienced',
#   'invasive',
#   'provide',
#   'quite',
#   'quarantine',
#   'eventually',
#   'active',
#   'becomes',
#   'execution',
#   'movements',
#   'north',
#   'ten',
#   'pandemic',
#   'taxpayer',
#   'directly',
#   'retrieve',
#   'galaxy',
#   'seemingly',
#   'heck',
#   'spyware',
#   'brother',
#   'field',
#   'become',
#   'maintaining',
#   'free',
#   'ur',
#   'freedom',
#   'tools',
#   'receiving',
#   'creates',
#   'professional',
#   'causes',
#   'bit',
#   'compared',
#   'top',
#   'ing',
#   'danger',
#   'taking',
#   'los',
#   'comfortable',
#   'spins',
#   'spreading',
#   'city',
#   'full',
#   'indicate',
#   'kinda',
#   'promoted',
#   'emails',
#   'honestly',
#   'sound',
#   'codes',
#   'dog',
#   'monday',
#   'millions',
#   'freedoms',
#   'entire',
#   'solution',
#   'connected',
#   'sensing',
#   'effectively',
#   'onto',
#   'suspect',
#   'warnings',
#   'la',
#   'intended',
#   'goes',
#   'delete',
#   'business',
#   'hoping',
#   'flaw',
#   'worth',
#   'admit',
#   'second',
#   'son',
#   'yorkers',
#   'nightmare',
#   'disappointing',
#   'warned',
#   'sketchy',
#   'employee',
#   'killing',
#   'wake',
#   'realize',
#   'bottom',
#   'releasing',
#   'child',
#   'hoax',
#   'redo',
#   'creating',
#   'ran',
#   'complaints',
#   'suggest',
#   'ppl',
#   'similar',
#   'screw',
#   'anymore',
#   'trouble',
#   'visit',
#   'weak',
#   'acceptable',
#   'spam',
#   'office',
#   'seconds',
#   'affected',
#   'developers',
#   'probably',
#   'included',
#   'recording',
#   'waiting',
#   'accept',
#   'create',
#   'hung',
#   'impossible',
#   'proud',
#   'poorly',
#   'mdh',
#   'understanding',
#   'worried',
#   'neighbor',
#   'spinning',
#   'diagnosis',
#   'pull',
#   'damn',
#   'husband',
#   'remind',
#   'tap',
#   'rapid',
#   ...],
#  ['told',
#   'mind',
#   'apple',
#   'soon',
#   'nj',
#   'horrible',
#   'utah',
#   'reason',
#   'option',
#   'via',
#   'twice',
#   'screen',
#   'difficult',
#   'came',
#   'masks',
#   'matter',
#   'page',
#   'slow',
#   'awesome',
#   'hour',
#   'vaccine',
#   'cant',
#   'birth',
#   'services',
#   'believe',
#   'super',
#   'tells',
#   'problems',
#   'rather',
#   'asking',
#   'response',
#   'whole',
#   'permission',
#   'hospital',
#   'essential',
#   'amazing',
#   'ios',
#   'medical',
#   'informative',
#   'require',
#   'anywhere',
#   'garbage',
#   'fantastic',
#   'effort',
#   'mine',
#   'reach',
#   'simply',
#   'alerted',
#   'guess',
#   'checks',
#   'reporting',
#   'joke',
#   'longer',
#   'design',
#   'power',
#   'prior',
#   'properly',
#   'visited',
#   'heard',
#   'trust',
#   'background',
#   'clearly',
#   'staff',
#   'cool',
#   'collect',
#   'bug',
#   'input',
#   'late',
#   'night',
#   'older',
#   'safety',
#   'unfortunately',
#   'wonderful',
#   'exactly',
#   'grocery',
#   'designed',
#   'gov',
#   'pass',
#   'frustrating',
#   'spent',
#   'space',
#   'face',
#   'coming',
#   'looks',
#   'bugs',
#   'interface',
#   'setting',
#   'blue',
#   'solution',
#   'difference',
#   'recently',
#   'company',
#   'account',
#   'high',
#   'immediately',
#   'drive',
#   'stats',
#   'loved',
#   'actual',
#   'center',
#   'proximity',
#   'stores',
#   'impressed',
#   'figure',
#   'vdh',
#   'full',
#   'choose',
#   'failure',
#   'statistics',
#   'saw',
#   'rating',
#   'watching',
#   'serious',
#   'questions',
#   'friendly',
#   'symptom',
#   'constantly',
#   'website',
#   'contacted',
#   'active',
#   'literally',
#   'terrible',
#   'submit',
#   'worry',
#   'folks',
#   'seriously',
#   'hoping',
#   'somebody',
#   'birthday',
#   'residents',
#   'step',
#   'mean',
#   'sign',
#   'entire',
#   'opened',
#   'removed',
#   'everybody',
#   'va',
#   'city',
#   'necessary',
#   'crashes',
#   'latest',
#   'death',
#   'florida',
#   'yesterday',
#   'correctly',
#   'pixel',
#   'crazy',
#   'morning',
#   'paid',
#   'rights',
#   'reading',
#   'neither',
#   'charging',
#   'tracks',
#   'bit',
#   'instructions',
#   'luck',
#   'huge',
#   'wi',
#   'pennsylvania',
#   'annoying',
#   'building',
#   'driving',
#   'across',
#   'peace',
#   'hate',
#   'incredibly',
#   'highly',
#   'brother',
#   'fear',
#   'minnesota',
#   'living',
#   'covidwise',
#   'mandatory',
#   'concerned',
#   'significant',
#   'request',
#   'ppl',
#   'situation',
#   'concerns',
#   'god',
#   'range',
#   'participate',
#   'showing',
#   'concern',
#   'happens',
#   'perfectly',
#   'large',
#   'guys',
#   'school',
#   'individuals',
#   'single',
#   'noticed',
#   'created',
#   'population',
#   'pa',
#   'taking',
#   'straight',
#   'similar',
#   'automatically',
#   'country',
#   'theory',
#   'quite',
#   'kinda',
#   'basically',
#   'built',
#   'line',
#   'especially',
#   'unobtrusive',
#   'poorly',
#   'specific',
#   'age',
#   'recorded',
#   'flaw',
#   'feet',
#   'accurately',
#   'turning',
#   'visit',
#   'amount',
#   'dead',
#   'execution',
#   'writing',
#   'distance',
#   'informed',
#   'ridiculous',
#   'press',
#   'asked',
#   'excited',
#   'focused',
#   'wonder',
#   'weird',
#   'doh',
#   'top',
#   'ensure',
#   'talking',
#   'functionality',
#   'january',
#   'jan',
#   'expected',
#   'additional',
#   'parents',
#   'activate',
#   'feedback',
#   'south',
#   'warned',
#   'explains',
#   'town',
#   'sites',
#   'missing',
#   'happened',
#   'double',
#   'pleased',
#   'confusing',
#   'extra',
#   'special',
#   'cell',
#   'trouble',
#   'fi',
#   'clicked',
#   'lost',
#   'reliable',
#   'seeing',
#   'wow',
#   'random',
#   'walk',
#   'sensitive',
#   'os',
#   'pop',
#   'patients',
#   'laws',
#   'ahead',
#   'collection',
#   'businesses',
#   'explain',
#   'personally',
#   'constant',
#   'providing',
#   'weekly',
#   'therefore',
#   'scan',
#   'intuitive',
#   'happen',
#   'original',
#   'everyday',
#   'voluntary',
#   'vaccinated',
#   'internal',
#   'hell',
#   'shut',
#   'sending',
#   'excelente',
#   'looked',
#   'mn',
#   'nurse',
#   'listed',
#   'hear',
#   'ca',
#   'responsible',
#   'dec',
#   'early',
#   'pay',
#   'spot',
#   'sunday',
#   'alone',
#   'id',
#   'written',
#   'red',
#   'apparently',
#   'assistance',
#   'comes',
#   'determine',
#   'ur',
#   'online',
#   'tooth',
#   'mostly',
#   'aside',
#   'happening',
#   'easily',
#   'period',
#   'prevent',
#   'unlike',
#   'complaints',
#   'diary',
#   'behind',
#   'creating',
#   'upset',
#   'hospitals',
#   'bunch',
#   'extremely',
#   'claims',
#   'solid',
#   'fully',
#   'lower',
#   'easier',
#   'economy',
#   'decided',
#   'sell',
#   'critical',
#   'regularly',
#   'following',
#   'experienced',
#   'benefit',
#   'followed',
#   'head',
#   'mess',
#   'voluntarily',
#   'ap',
#   'calling',
#   'encounters',
#   'provided',
#   'vaccination',
#   'deaths',
#   'turns',
#   'smartphone',
#   'honest',
#   'cuz',
#   'previous',
#   'winter',
#   'york',
#   'applications',
#   'mention',
#   'interactions',
#   'diagnosis',
#   'select',
#   'widely',
#   'hi',
#   'body',
#   'unlock',
#   'discovered',
#   'third',
#   'confirm',
#   'numerous',
#   'announced',
#   'forced',
#   'bt',
#   'doctors',
#   'misleading',
#   'tab',
#   'become',
#   'cuomo',
#   'finding',
#   'outbreak',
#   'october',
#   'rely',
#   'anonymously',
#   'valuable',
#   'suggestion',
#   'frequently',
#   'lots',
#   'increase',
#   'sometimes',
#   'spam',
#   'elderly',
#   'children',
#   'arizona',
#   'michigan',
#   'surprised',
#   'combat',
#   'relies',
#   'couple',
#   'dumb',
#   'nc',
#   'portion',
#   'room',
#   'putting',
#   'became',
#   'hog',
#   'drove',
#   'create',
#   'impact',
#   'bother',
#   'requested',
#   'developing',
#   'kill',
#   'sheep',
#   'maryland',
#   'accuracy',
#   'sitting',
#   'loaded',
#   'party',
#   'blind',
#   'passed',
#   'loads',
#   'violation',
#   'separate',
#   'display',
#   'offered',
#   'along',
#   'appreciated',
#   'average',
#   'nursing',
#   'steps',
#   'thankfully',
#   'switch',
#   'rest',
#   'attention',
#   'provider',
#   'biggest',
#   'rates',
#   'nearby',
#   'disease',
#   'alabama',
#   'percent',
#   'bottom',
#   'co',
#   'allergies',
#   'buggy',
#   'plenty',
#   'indicate',
#   'screenshot',
#   'md',
#   'reasons',
#   'die',
#   'thru',
#   'agree',
#   'acceptable',
#   'forever',
#   'scroll',
#   'write',
#   'gracias',
#   'eventually',
#   'field',
#   'idk',
#   'lie',
#   'americans',
#   'encourage',
#   'absolute',
#   'pray',
#   'car',
#   'contagious',
#   'spend',
#   'invasive',
#   'paper',
#   'helped',
#   'sooner',
#   'hipaa',
#   'valid',
#   'overnight',
#   'moved',
#   'force',
#   'nightmare',
#   'screens',
#   'focus',
#   'patient',
#   'attempt',
#   'accept',
#   'relief',
#   'higher',
#   'directly',
#   'clinic',
#   'fake',
#   'ct',
#   'signal',
#   'quarantined',
#   'child',
#   'que',
#   'warn',
#   'monitoring',
#   'peoples',
#   'broken',
#   'federal',
#   'scam',
#   'china',
#   'complaint',
#   'national',
#   'earlier',
#   'selecting',
#   'november',
#   'pcr',
#   'danger',
#   'pro',
#   'grateful',
#   'per',
#   'crashing',
#   'members',
#   'fall',
#   'survival',
#   'immune',
#   'okay',
#   'hopeful',
#   'spouse',
#   'beat',
#   'wanting',
#   'noted',
#   'ill',
#   'key',
#   'box',
#   'complicated',
#   'upload',
#   'customer',
#   'auto',
#   'whatever',
#   'friday',
#   'wide',
#   'tools',
#   'entry',
#   'tho',
#   'match',
#   'office',
#   'contract',
#   'felt',
#   'officials',
#   'suggest',
#   'effectiveness',
#   'outside',
#   'traveled',
#   'directions',
#   'activated',
#   'immediate',
#   'north',
#   'dark',
#   'explanation',
#   'navigate',
#   'allows',
#   'gonna',
#   'loving',
#   'unnecessary',
#   'spy',
#   'non',
#   'individual',
#   'optional',
#   'icon',
#   'decent',
#   'described',
#   'rolled',
#   'hold',
#   'convenient',
#   'incorrect',
#   'buena',
#   'tracers',
#   'alerting',
#   'picked',
#   'professional',
#   'sadly',
#   'registered',
#   'lying',
#   'graphs',
#   'tech',
#   'scared',
#   'sound',
#   'disabled',
#   'walking',
#   'intended',
#   'connection',
#   'speak',
#   'beta',
#   'proper',
#   'cvs',
#   'requirement',
#   'energy',
#   'sad',
#   'everytime',
#   'hurt',
#   'april',
#   'inform',
#   'corrected',
#   'worried',
#   'welcome',
#   'efforts',
#   'ideal',
#   'unfortunate',
#   'spreading',
#   'mentioned',
#   'saved',
#   'reviewers',
#   'implementation',
#   'toggle',
#   'listen',
#   'cellphone',
#   'dc',
#   'throughout',
#   'compared',
#   'remain',
#   'hippa',
#   'breakdown',
#   'search',
#   'birthdate',
#   'unconstitutional',
#   'citizens',
#   'restarted',
#   'language',
#   'looking',
#   'employees',
#   'major',
#   'sanitizer',
#   'busy',
#   'entirely',
#   'plague',
#   'december',
#   'mile',
#   'instructed',
#   'american',
#   'puts',
#   'interested',
#   'screw',
#   'usual',
#   'staying',
#   'completed',
#   'business',
#   'lies',
#   'rhode',
#   'ble',
#   'mail',
#   'reduce',
#   'levels',
#   'except',
#   'unknown',
#   'inactive',
#   'idiots',
#   'purchase',
#   'highest',
#   'measures',
#   'alot',
#   'iphones',
#   'proud',
#   'mdh',
#   'closed',
#   'diagnosed',
#   'typical',
#   'missed',
#   'unusable',
#   'hawaii',
#   'specifically',
#   'convinced',
#   'trips',
#   'facility',
#   'forcing',
#   'nation',
#   'crash',
#   'en',
#   'according',
#   'annoyance',
#   'story',
#   'actively',
#   'asap',
#   'allowed',
#   'confirmation',
#   'automated',
#   'logging',
#   'choice',
#   'emails',
#   'storage',
#   'stopping',
#   'notifying',
#   'positivity',
#   'street',
#   'wolf',
#   'notices',
#   'wake',
#   'opinion',
#   'imagine',
#   'wait',
#   'spins',
#   'scanning',
#   'dollars',
#   'whoever',
#   'precautions',
#   'return',
#   'adds',
#   'drop',
#   'shown',
#   'scary',
#   'virginian',
#   'wa',
#   'leadership',
#   'statewide',
#   'answered',
#   'detected',
#   'requiring',
#   'comments',
#   'limited',
#   'consent',
#   'changing',
#   'companies',
#   'vs',
#   'vital',
#   'server',
#   'six',
#   'logs',
#   'junk',
#   'corona',
#   'movement',
#   'identity',
#   'exposing',
#   'communicate',
#   'disable',
#   'mainly',
#   'nationwide',
#   'emergency',
#   'suggestions',
#   'se',
#   'died',
#   'distancing',
#   'mi',
#   'white',
#   'functioning',
#   'failed',
#   'stated',
#   'detect',
#   'trusted',
#   'locate',
#   'scrolling',
#   'mass',
#   'hit',
#   'hundred',
#   'depends',
#   'blocks',
#   'bc',
#   'ing',
#   'significantly',
#   'threat',
#   'comprehensive',
#   'admit',
#   'jump',
#   'hopes',
#   'english',
#   'scare',
#   'millions',
#   'default',
#   'years',
#   'appt',
#   'vaccines',
#   'september',
#   'half',
#   'receiving',
#   'human',
#   'developed',
#   'island',
#   'straightforward',
#   'failing',
#   'experiencing',
#   'advised',
#   'effect',
#   'involved',
#   'functional',
#   'facebook',
#   'initiative',
#   'expect',
#   'appear',
#   'generate',
#   'counter',
#   'virginians',
#   'unique',
#   'compatible',
#   'wondering',
#   'promoted',
#   'serves',
#   'slowcovidnc',
#   'tax',
#   'fails',
#   'letting',
#   'max',
#   'political',
#   'onto',
#   'fill',
#   'existed',
#   'communities',
#   'ease',
#   'nd',
#   'lucky',
#   'manner',
#   'nys',
#   'launch',
#   'families',
#   'suppose',
#   'trip',
#   'usually',
#   'reload',
#   'proceed',
#   'wash',
#   'randomly',
#   'verified',
#   'walks',
#   'reset',
#   'quicker',
#   'network',
#   'monday',
#   'options',
#   'crush',
#   'john',
#   'middle',
#   'wasted',
#   'notes',
#   'successful',
#   'sister',
#   'implemented',
#   'password',
#   'mom',
#   'opening',
#   'daughter',
#   'ineffective',
#   'racial',
#   'avoid',
#   'lol',
#   'shot',
#   'guy',
#   'faq',
#   'considered',
#   'conditions',
#   'indicates',
#   'spending',
#   'citizen',
#   'wrote',
#   'incredible',
#   'forgot',
#   'charged',
#   'points',
#   'virtually',
#   'informing',
#   'anybody',
#   'eat',
# ...
#   'addresses',
#   'dashboard',
#   'family',
#   'permanently',
#   'deaths',
#   'goal',
#   'walking',
#   'misleading',
#   'constant',
#   'come',
#   'scare',
#   'portion',
#   'pay',
#   'implemented',
#   'buena',
#   'understanding',
#   'basically',
#   'survive',
#   'infection',
#   'bad',
#   'freedoms',
#   'typical',
#   'entire',
#   'loop',
#   'reinstall',
#   'isolate',
#   'address',
#   'engineer',
#   'updating',
#   'easier',
#   'levels',
#   'rhode',
#   'join',
#   'charging',
#   'gov',
#   'magic',
#   'instructions',
#   'instantly',
#   'election',
#   'galaxy',
#   'busy',
#   'beneficial',
#   'advertised',
#   'reliable',
#   'allowing',
#   'email',
#   'respond',
#   'jump',
#   'danger',
#   'actively',
#   'explained',
#   'language',
#   'complaints',
#   'quicker',
#   'anonymity',
#   'regardless',
#   'exactly',
#   'regarding',
#   'runs',
#   'annoyance',
#   'birthdate',
#   'comprehensive',
#   'situation',
#   'lie',
#   'displayed',
#   'seemingly',
#   'weekend',
#   'button',
#   'level',
#   'crash',
#   'alot',
#   'online',
#   'ready',
#   'claims',
#   'additional',
#   'reminder',
#   'groceries',
#   'click',
#   'attempts',
#   'dying',
#   'looked',
#   'university',
#   'whose',
#   'afternoon',
#   'diagnosis',
#   'wonder',
#   'fall',
#   'participate',
#   'dc',
#   'light',
#   'execution',
#   'based',
#   'age',
#   'points',
#   'members',
#   'whats',
#   'encountered',
#   'smooth',
#   'installs',
#   'looks',
#   'living',
#   'writing',
#   'star',
#   'collection',
#   'felt',
#   'responding',
#   'caught',
#   'ineffective',
#   'source',
#   'agree',
#   'redo',
#   'dozens',
#   'faq',
#   'identity',
#   'convenient',
#   'hold',
#   'software',
#   'relies',
#   'advised',
#   'spinning',
#   'trouble',
#   'paid',
#   'appears',
#   'hell',
#   'remind',
#   'category',
#   'pixel',
#   'provide',
#   'street',
#   'signal',
#   'afraid',
#   'driver',
#   'child',
#   'random',
#   'relevant',
#   'feeling',
#   'attention',
#   'worse',
#   'rid',
#   'became',
#   'strangers',
#   'developed',
#   'happen',
#   'filled',
#   'retail',
#   'continue',
#   'body',
#   'upon',
#   'mdh',
#   'signed',
#   'inactive',
#   'contagious',
#   'things',
#   'scrolling',
#   'suspect',
#   'delay',
#   'thus',
#   'providing',
#   'charged',
#   'indicates',
#   'records',
#   'mainly',
#   'continues',
#   'means',
#   'doesnt',
#   'proof',
#   'perhaps',
#   'mandatory',
#   'area',
#   'years',
#   'sources',
#   'answered',
#   'list',
#   'suddenly',
#   'till',
#   'status',
#   'currently',
#   'allergies',
#   'rest',
#   'communicate',
#   'driving',
#   'unique',
#   'protection',
#   'simply',
#   'hoping',
#   'rarely',
#   'night',
#   'straightforward',
#   'un',
#   'made',
#   'retrieve',
#   'plague',
#   'consistent',
#   'ultra',
#   'maintaining',
#   'removing',
#   'corona',
#   'ny',
#   'calling',
#   'totally',
#   'caused',
#   'big',
#   'neighbors',
#   'idk',
#   'spins',
#   'numerous',
#   'happened',
#   'errors',
#   'automatically',
#   'ran',
#   'operating',
#   'locally',
#   'weekly',
#   'invasive',
#   'covidwise',
#   'gonna',
#   'slider',
#   'helping',
#   'clue',
#   'requirements',
#   'ensure',
#   'focused',
#   'reasons',
#   'supporting',
#   'communication',
#   'sanitizer',
#   'proud',
#   'millions',
#   'key',
#   'determine',
#   'written',
#   'away',
#   'existed',
#   'unfortunate',
#   'internal',
#   'racial',
#   'widely',
#   'learn',
#   'concerned',
#   'installation',
#   'charge',
#   'scanning',
#   'disappointing',
#   'pleasant',
#   'party',
#   'specifically',
#   'hung',
#   'size',
#   'outbreak',
#   'collected',
#   'wa',
#   'section',
#   'grocery',
#   'adopt',
#   'spend',
#   'connections',
#   'putting',
#   'youtube',
#   'imagine',
#   'clever',
#   'eventually',
#   'yorkers',
#   'sense',
#   'seeing',
#   'vdh',
#   'sharing',
#   'happening',
#   'mongering',
#   'pointless',
#   'approach',
#   'promoted',
#   'vulnerable',
#   'interactions',
#   'asked',
#   'fail',
#   'throat',
#   'spending',
#   'active',
#   'choose',
#   'initiative',
#   'groups',
#   'requested',
#   'blind',
#   'alerted',
#   'executed',
#   ...],
#  ['contact',
#   'location',
#   'give',
#   'help',
#   'see',
#   'update',
#   'send',
#   'code',
#   'one',
#   'go',
#   'part',
#   'please',
#   'time',
#   'think',
#   'call',
#   'provide',
#   'work',
#   'back',
#   'get',
#   'life',
#   'us',
#   'show',
#   'info',
#   'track',
#   'great',
#   'enough',
#   'issues',
#   'information',
#   'phone',
#   'never',
#   'order',
#   'job',
#   'people',
#   'test',
#   'download',
#   'good',
#   'would',
#   'bluetooth',
#   'remove',
#   'tested',
#   'map',
#   'results',
#   'positive',
#   'need',
#   'easy',
#   'idea',
#   'like',
#   'use',
#   'installed',
#   'thank',
#   'someone',
#   'places',
#   'even',
#   'covid',
#   'useless',
#   'everyone',
#   'privacy',
#   'notification',
#   'state',
#   'since',
#   'way',
#   'notifications',
#   'keep',
#   'also',
#   'delete',
#   'make',
#   'link',
#   'exposed',
#   'still',
#   'could',
#   'downloaded',
#   'says',
#   'tracing',
#   'days',
#   'problem',
#   'virus',
#   'tell',
#   'others',
#   'report',
#   'google',
#   'anyone',
#   'without',
#   'open',
#   'alert',
#   'may',
#   'wrong',
#   'know',
#   'day',
#   'really',
#   'point',
#   'helpful',
#   'safe',
#   'screen',
#   'example',
#   'refresh',
#   'first',
#   'well',
#   'battery',
#   'works',
#   'updated',
#   'ask',
#   'apple',
#   'much',
#   'data',
#   'better',
#   'want',
#   'cannot',
#   'let',
#   'nothing',
#   'home',
#   'text',
#   'got',
#   'install',
#   'notify',
#   'quick',
#   'longer',
#   'android',
#   'share',
#   'find',
#   'tracking',
#   'best',
#   'review',
#   'exposures',
#   'already',
#   'security',
#   'exposure',
#   'many',
#   'notified',
#   'tool',
#   'keeps',
#   'phones',
#   'newline',
#   'minutes',
#   'turn',
#   'deleted',
#   'pretty',
#   'load',
#   'number',
#   'apps',
#   'needs',
#   'times',
#   'using',
#   'add',
#   'seems',
#   'feel',
#   'anything',
#   'health',
#   'user',
#   'every',
#   'stop',
#   'months',
#   'waste',
#   'option',
#   'reported',
#   'something',
#   'might',
#   'requires',
#   'samsung',
#   'able',
#   'yet',
#   'saw',
#   'refuse',
#   'wish',
#   'mask',
#   'person',
#   'next',
#   'working',
#   'check',
#   'getting',
#   'tried',
#   'right',
#   'fix',
#   'read',
#   'sure',
#   'asking',
#   'enable',
#   'last',
#   'available',
#   'maybe',
#   'edit',
#   'finally',
#   'department',
#   'two',
#   'infected',
#   'awesome',
#   'simple',
#   'least',
#   'pin',
#   'try',
#   'permission',
#   'type',
#   'uninstalled',
#   'far',
#   'accurate',
#   'risk',
#   'glad',
#   'enter',
#   'running',
#   'service',
#   'run',
#   'actually',
#   'lot',
#   'though',
#   'hope',
#   'helps',
#   'gps',
#   'quickly',
#   'said',
#   'past',
#   'government',
#   'system',
#   'weeks',
#   'noticed',
#   'play',
#   'nj',
#   'page',
#   'symptoms',
#   'trust',
#   'result',
#   'possible',
#   'take',
#   'name',
#   'hour',
#   'told',
#   'space',
#   'nice',
#   'address',
#   'pandemic',
#   'completely',
#   'love',
#   'horrible',
#   'went',
#   'put',
#   'error',
#   'guess',
#   'thanks',
#   'question',
#   'needed',
#   'spread',
#   'stupid',
#   'settings',
#   'secure',
#   'support',
#   'high',
#   'locations',
#   'gave',
#   'developer',
#   'require',
#   'response',
#   'age',
#   'slow',
#   'pass',
#   'probably',
#   'daily',
#   'medical',
#   'access',
#   'happy',
#   'new',
#   'hours',
#   'virginia',
#   'important',
#   'came',
#   'live',
#   'via',
#   'cant',
#   'joke',
#   'turned',
#   'going',
#   'downloading',
#   'mind',
#   'uses',
#   'wifi',
#   'properly',
#   'wonderful',
#   'leave',
#   'another',
#   'place',
#   'makes',
#   'dont',
#   'fact',
#   'issue',
#   'testing',
#   'reason',
#   'creating',
#   'proximity',
#   'little',
#   'worked',
#   'excellent',
#   'stops',
#   'jersey',
#   'sick',
#   'cool',
#   'birth',
#   'follow',
#   'gets',
#   'receive',
#   'numbers',
#   'power',
#   'unable',
#   'believe',
#   'hopefully',
#   'tells',
#   'took',
#   'lives',
#   'technology',
#   'twice',
#   'reporting',
#   'iphone',
#   'less',
#   'required',
#   'takes',
#   'goes',
#   'random',
#   'care',
#   'aside',
#   'confusing',
#   'proud',
#   'trying',
#   'definitely',
#   'questions',
#   'likely',
#   'unfortunately',
#   'serious',
#   'ever',
#   'utah',
#   'convenient',
#   'stay',
#   'setting',
#   'around',
#   'county',
#   'ago',
#   'useful',
#   'garbage',
#   'january',
#   'permissions',
#   'installing',
#   'change',
#   'crush',
#   'services',
#   'start',
#   'wheel',
#   'wife',
#   'weekly',
#   'intuitive',
#   'inform',
#   'frequently',
#   'used',
#   'tracker',
#   'absolutely',
#   'stopped',
#   'view',
#   'families',
#   'concept',
#   'checks',
#   'leaders',
#   'say',
#   'bug',
#   'extra',
#   'seriously',
#   'description',
#   'feature',
#   'devices',
#   'received',
#   'pointless',
#   'voluntarily',
#   'reinstalled',
#   'today',
#   'clearly',
#   'thing',
#   'allow',
#   'created',
#   'surprised',
#   'prior',
#   'knows',
#   'showing',
#   'control',
#   'agency',
#   'major',
#   'difficult',
#   'save',
#   'pull',
#   'national',
#   'participate',
#   'updates',
#   'higher',
#   'dept',
#   'paranoid',
#   'concern',
#   'cases',
#   'lies',
#   'talking',
#   'mass',
#   'instead',
#   'staff',
#   'employee',
#   'inaccurate',
#   'site',
#   'alot',
#   'recommend',
#   'quicker',
#   'currently',
#   'click',
#   'drains',
#   'records',
#   'record',
#   'threat',
#   'governor',
#   'whole',
#   'reports',
#   'york',
#   'nose',
#   'background',
#   'folks',
#   'api',
#   'choice',
#   'huge',
#   'matter',
#   'trigger',
#   'loss',
#   'citizens',
#   'john',
#   'china',
#   'birthdate',
#   'literally',
#   'anonymous',
#   'supposed',
#   'faith',
#   'note',
#   'fantastic',
#   'informed',
#   'requested',
#   'realize',
#   'indicator',
#   'month',
#   'permanently',
#   'private',
#   'remind',
#   'device',
#   'applications',
#   'verification',
#   'scary',
#   'soon',
#   'log',
#   'instructions',
#   'normally',
#   'level',
#   'alabama',
#   'saying',
#   'immediately',
#   'extremely',
#   'relies',
#   'set',
#   'nation',
#   'confirmed',
#   'section',
#   'difference',
#   'sending',
#   'responding',
#   'simply',
#   'freedom',
#   'statistics',
#   'asap',
#   'appointment',
#   'states',
#   'choose',
#   'leaving',
#   'ready',
#   'god',
#   'solid',
#   'offer',
#   'fair',
#   'paranoia',
#   'patients',
#   'concerned',
#   'warn',
#   'registration',
#   'sunday',
#   'responsible',
#   'constantly',
#   'wow',
#   'vaccine',
#   'roll',
#   'mdh',
#   'family',
#   'consistently',
#   'gov',
#   'en',
#   'ineffective',
#   'thus',
#   'green',
#   'dc',
#   'bottom',
#   'manual',
#   'manually',
#   'entered',
#   'walked',
#   'loads',
#   'stats',
#   'seeing',
#   'checked',
#   'solution',
#   'obviously',
#   'actively',
#   'shared',
#   'yesterday',
#   'developers',
#   'killed',
#   'highly',
#   'flawed',
#   'rather',
#   'trouble',
#   'significant',
#   'showed',
#   'lost',
#   'found',
#   'entry',
#   'none',
#   'collected',
#   'minnesota',
#   'informative',
#   'interested',
#   'election',
#   'hundreds',
#   'date',
#   'happens',
#   'stuck',
#   'users',
#   'near',
#   'negative',
#   'displayed',
#   'addition',
#   'things',
#   'hate',
#   'board',
#   'active',
#   'incorrect',
#   'night',
#   'doubt',
#   'wa',
#   'shows',
#   'interface',
#   'constant',
#   'se',
#   'situation',
#   'covidwise',
#   'deleting',
#   'done',
#   'pain',
#   'looks',
#   'drive',
#   'explain',
#   'contacted',
#   'california',
#   'weekend',
#   'sketchy',
#   'faster',
#   'reach',
#   'double',
#   'basic',
#   'parking',
#   'deaths',
#   'affected',
#   'letting',
#   'quarantine',
#   'within',
#   'living',
#   'claims',
#   'designed',
#   'distancing',
#   'eventually',
#   'utilize',
#   'protect',
#   'america',
#   'spent',
#   'downloads',
#   'party',
#   'emailed',
#   'pray',
#   'straight',
#   'keeping',
#   'clicking',
#   'border',
#   'upload',
#   'va',
#   'world',
#   'personal',
#   'indicate',
#   'survival',
#   'provides',
#   'lie',
#   'tracers',
#   'broken',
#   'freedoms',
#   'stored',
#   'disappointed',
#   'outside',
#   'robert',
#   'anywhere',
#   'red',
#   'neighbors',
#   'determine',
#   'earlier',
#   'model',
#   'moto',
#   'bring',
#   'saves',
#   'guys',
#   'movements',
#   'large',
#   'removed',
#   'relevant',
#   'talk',
#   'smart',
#   'economy',
#   'isolate',
#   'importance',
#   'circle',
#   'feedback',
#   'long',
#   'schools',
#   'inactive',
#   'considering',
#   'advise',
#   'informing',
#   'faq',
#   'request',
#   'worst',
#   'waiting',
#   'totally',
#   'explains',
#   'added',
#   'hurt',
#   'adds',
#   'racial',
#   'fight',
#   'integrated',
#   'push',
#   'goal',
#   'participating',
#   'ap',
#   'energy',
#   'self',
#   'however',
#   'paid',
#   'dying',
#   'caused',
#   'detected',
#   'explanation',
#   'portion',
#   'voluntary',
#   'following',
#   'started',
#   'store',
#   'worried',
#   'step',
#   'addresses',
#   'instantly',
#   'cell',
#   'must',
#   'newest',
#   'hacking',
#   'hear',
#   'spy',
#   'design',
#   'heck',
#   'annoying',
#   'rights',
#   'park',
#   'existed',
#   'gives',
#   'intentions',
#   'recently',
#   'top',
#   'terrible',
#   'setup',
#   'finding',
#   'facility',
#   'create',
#   'mainly',
#   'claiming',
#   'frustrating',
#   'spreading',
#   'taking',
#   'course',
#   'danger',
#   'rhode',
#   'worthless',
#   'nonsense',
#   'updating',
#   'percentage',
#   'ill',
#   'mine',
#   'unusable',
#   'misleading',
#   'whats',
#   'moment',
#   'notice',
#   'beat',
#   'met',
#   'wearing',
#   'afternoon',
#   'hangs',
#   'reload',
#   'satisfied',
#   'warned',
#   'recording',
#   'super',
#   'combat',
#   'uninstall',
#   'effort',
#   'walk',
#   'magic',
#   'allowing',
#   'adjust',
#   'receiving',
#   'drain',
#   'problems',
#   'caught',
#   'movement',
#   'tablet',
#   'points',
#   'repeatedly',
#   'separate',
#   'write',
#   'adoption',
#   'monday',
#   'kids',
#   'apart',
#   'visited',
#   'miss',
#   'uninstalling',
#   'unknown',
#   'children',
#   'morning',
#   'immune',
#   'continue',
#   'doesnt',
#   'figure',
#   'trace',
#   'dr',
#   'everything',
#   'quarantining',
#   'science',
#   'american',
#   'crash',
#   'checking',
#   'evening',
#   'initially',
#   'contagious',
#   'effectively',
#   'sister',
#   'er',
#   'options',
#   'function',
#   'respect',
#   'additional',
#   'counter',
#   'registered',
#   'exactly',
#   'application',
#   'amazing',
#   'pleased',
#   'understand',
#   'nobody',
#   'four',
#   'granted',
#   'come',
#   'directly',
#   'valuable',
#   'bit',
#   'anonymously',
#   'assuming',
#   'company',
#   'charging',
#   'safety',
#   'occasions',
#   'field',
#   'online',
#   'delivery',
#   'white',
#   'sucks',
#   'maintaining',
#   'stating',
#   'reality',
#   'explained',
#   'catch',
#   'locked',
#   'pcr',
#   'leaves',
#   'sake',
#   'meant',
#   'sensing',
#   'generate',
#   'identity',
#   'written',
#   'que',
#   'pocket',
#   'enabled',
#   'elderly',
#   'weak',
#   'killing',
#   'man',
#   'country',
#   'cdc',
#   'reliable',
#   'easily',
#   'input',
#   'essentially',
#   'helping',
#   'virtually',
#   'dog',
#   'wolf',
#   'knew',
#   'centers',
#   'blue',
#   'areas',
#   'unacceptable',
#   'center',
#   'dashboard',
#   'regularly',
#   'bed',
#   'yorkers',
#   'advertising',
#   'entirely',
#   'understanding',
#   'groceries',
#   'sitting',
#   'customer',
#   'alerted',
#   'levels',
#   'search',
#   'refuses',
#   'correctly',
#   'quite',
#   'infection',
#   'island',
#   'seconds',
#   'december',
#   'adopt',
#   'icon',
#   'fall',
#   'typical',
#   'youtube',
#   'damn',
#   'vdh',
#   'annoyance',
#   'forced',
#   'ble',
#   'driver',
#   'allowed',
#   'given',
#   'writing',
#   'neighbor',
#   'kills',
#   'terms',
#   'tab',
#   'food',
#   'interstate',
#   'disease',
#   'incredible',
#   'collecting',
#   'promoted',
#   'gonna',
#   'sign',
#   'process',
#   'lacks',
#   'survive',
#   'comfortable',
#   'execution',
#   'keys',
#   'locally',
#   'mandatory',
#   'sits',
#   'basis',
#   'media',
#   'regardless',
#   'max',
#   'complaint',
#   'july',
#   'wi',
#   'collection',
#   'sadly',
#   'jump',
#   'move',
#   'proof',
#   'crashing',
#   'mn',
#   'finish',
#   'words',
#   'kept',
#   'copy',
#   'exposing',
#   'theory',
#   'rarely',
#   'program',
#   'cough',
#   'countries',
#   'switch',
#   'body',
#   'drop',
#   'directions',
#   'bad',
#   'fine',
#   'pay',
#   'un',
#   'providing',
#   'frustrated',
#   'accurately',
#   'hey',
#   'minor',
#   'retail',
#   'warnings',
#   'disappointing',
#   'became',
#   'watching',
#   'behind',
#   'sanitizer',
#   'beware',
#   'fighting',
#   'encounters',
#   'ensure',
#   'collect',
#   'tracer',
#   'vital',
#   'ios',
#   'tho',
#   'allows',
#   'traveled',
#   'dec',
#   'confidence',
#   'recorded',
#   'alerts',
#   'count',
#   'serves',
#   'talked',
#   'else',
#   'saver',
#   'personally',
#   'respond',
#   'outbreak',
#   'millions',
#   'interview',
#   'winter',
#   'beneficial',
#   'poorly',
#   'announced',
#   'departments',
#   'protection',
#   'de',
#   'listed',
#   'errors',
#   'regular',
#   'admit',
#   'appears',
#   'reasons',
#   'zero',
#   'picked',
#   'disappeared',
#   'activate',
#   'companies',
#   'removing',
#   'onto',
#   'spending',
#   'spyware',
#   'nys',
#   'whose',
#   'initiative',
#   'sd',
#   'texted',
#   'somebody',
#   'flaw',
#   'dozens',
#   'business',
#   'answered',
#   'incredibly',
#   'star',
#   'grocery',
#   'addressed',
#   'missing',
#   'efforts',
#   'single',
#   'register',
#   'framework',
#   'listen',
#   'six',
#   'tooth',
#   'guidelines',
#   'old',
#   'decision',
#   'brother',
#   'taste',
#   'widely',
#   'spinning',
#   'residents',
#   'web',
#   'truth',
#   'exist',
#   'wont',
#   'loaded',
#   'graphs',
#   ...]]

# %%
#20 words
top_20_ctm = ctm.get_topic_lists(20)
top_20_ctm
# Out:
# [['use',
#   'get',
#   'time',
#   'easy',
#   'us',
#   'way',
#   'think',
#   'useful',
#   'thing',
#   'one',
#   'wrong',
#   'things',
#   'everything',
#   'put',
#   'working',
#   'give',
#   'idea',
#   'people',
#   'take',
#   'go'],
#  ['even',
#   'google',
#   'completely',
#   'far',
#   'minutes',
#   'start',
#   'finally',
#   'possible',
#   'mask',
#   'already',
#   'gets',
#   'county',
#   'glad',
#   'android',
#   'numbers',
#   'enter',
#   'government',
#   'least',
#   'developer',
#   'wifi'],
#  ['something',
#   'new',
#   'since',
#   'actually',
#   'report',
#   'well',
#   'turn',
#   'hope',
#   'thanks',
#   'much',
#   'say',
#   'love',
#   'safe',
#   'hours',
#   'alert',
#   'checked',
#   'ago',
#   'stars',
#   'cases',
#   'family'],
#  ['told',
#   'mind',
#   'apple',
#   'soon',
#   'nj',
#   'horrible',
#   'utah',
#   'reason',
#   'option',
#   'via',
#   'twice',
#   'screen',
#   'difficult',
#   'came',
#   'masks',
#   'matter',
#   'page',
#   'slow',
#   'awesome',
#   'hour'],
#  ['notifications',
#   'thank',
#   'idea',
#   'phone',
#   'tracking',
#   'download',
#   'find',
#   'number',
#   'downloaded',
#   'waste',
#   'department',
#   'installed',
#   'notification',
#   'stop',
#   'fix',
#   'notify',
#   'notified',
#   'found',
#   'available',
#   'wish'],
#  ['love',
#   'however',
#   'report',
#   'spread',
#   'received',
#   'alert',
#   'since',
#   'actually',
#   'well',
#   'ago',
#   'turn',
#   'today',
#   'week',
#   'verification',
#   'much',
#   'else',
#   'safe',
#   'family',
#   'thanks',
#   'say'],
#  ['access',
#   'notification',
#   'notify',
#   'needs',
#   'installed',
#   'tracking',
#   'alerts',
#   'need',
#   'number',
#   'phone',
#   'open',
#   'downloaded',
#   'find',
#   'download',
#   'notified',
#   'stop',
#   'save',
#   'thank',
#   'needed',
#   'waste'],
#  ['know',
#   'exposure',
#   'install',
#   'right',
#   'last',
#   'data',
#   'allow',
#   'setup',
#   'uninstall',
#   'date',
#   'asks',
#   'concept',
#   'system',
#   'application',
#   'home',
#   'im',
#   'list',
#   'contacts',
#   'process',
#   'social'],
#  ['covid',
#   'battery',
#   'going',
#   'tried',
#   'seems',
#   'permissions',
#   'saying',
#   'went',
#   'trying',
#   'pin',
#   'started',
#   'anonymous',
#   'almost',
#   'quarantine',
#   'wants',
#   'nobody',
#   'uninstalling',
#   'waiting',
#   'wanted',
#   'installing'],
#  ['safe',
#   'since',
#   'hope',
#   'received',
#   'love',
#   'spread',
#   'much',
#   'store',
#   'alert',
#   'new',
#   'turn',
#   'actually',
#   'report',
#   'something',
#   'well',
#   'long',
#   'verification',
#   'thanks',
#   'else',
#   'however'],
#  ['hour',
#   'apple',
#   'space',
#   'background',
#   'told',
#   'mine',
#   'cant',
#   'correctly',
#   'screen',
#   'extremely',
#   'informative',
#   'informed',
#   'response',
#   'trust',
#   'unfortunately',
#   'page',
#   'checks',
#   'saw',
#   'problems',
#   'came'],
#  ['easy',
#   'get',
#   'use',
#   'way',
#   'us',
#   'time',
#   'useful',
#   'thing',
#   'think',
#   'wrong',
#   'working',
#   'things',
#   'everything',
#   'one',
#   'put',
#   'given',
#   'take',
#   'worked',
#   'check',
#   'health'],
#  ['keep',
#   'without',
#   'tested',
#   'others',
#   'want',
#   'someone',
#   'still',
#   'test',
#   'nothing',
#   'though',
#   'keeps',
#   'first',
#   'another',
#   'useless',
#   'never',
#   'past',
#   'testing',
#   'accurate',
#   'anyone',
#   'yet'],
#  ['code',
#   'go',
#   'back',
#   'one',
#   'enough',
#   'tell',
#   'wrong',
#   'home',
#   'lot',
#   'share',
#   'contact',
#   'name',
#   'quick',
#   'show',
#   'system',
#   'order',
#   'data',
#   'job',
#   'give',
#   'leave'],
#  ['like',
#   'results',
#   'everyone',
#   'got',
#   'uses',
#   'day',
#   'people',
#   'using',
#   'positive',
#   'sure',
#   'able',
#   'getting',
#   'state',
#   'really',
#   'days',
#   'around',
#   'anything',
#   'many',
#   'every',
#   'times'],
#  ['good',
#   'make',
#   'also',
#   'help',
#   'update',
#   'excellent',
#   'location',
#   'places',
#   'issues',
#   'happy',
#   'helpful',
#   'issue',
#   'updated',
#   'added',
#   'provide',
#   'provides',
#   'receive',
#   'send',
#   'helping',
#   'deleted'],
#  ['could',
#   'tracing',
#   'newline',
#   'apps',
#   'gps',
#   'stops',
#   'months',
#   'settings',
#   'dont',
#   'uninstalled',
#   'weeks',
#   'would',
#   'iphone',
#   'downloading',
#   'might',
#   'may',
#   'privacy',
#   'says',
#   'month',
#   'took'],
#  ['information',
#   'problem',
#   'track',
#   'please',
#   'info',
#   'review',
#   'live',
#   'life',
#   'point',
#   'call',
#   'part',
#   'locations',
#   'enable',
#   'care',
#   'ask',
#   'tool',
#   'fact',
#   'service',
#   'text',
#   'local'],
#  ['works',
#   'health',
#   'let',
#   'check',
#   'error',
#   'working',
#   'better',
#   'nice',
#   'take',
#   'gives',
#   'worked',
#   'put',
#   'giving',
#   'important',
#   'self',
#   'given',
#   'everything',
#   'issue',
#   'change',
#   'helpful'],
#  ['useless',
#   'yet',
#   'first',
#   'test',
#   'still',
#   'never',
#   'others',
#   'nothing',
#   'tested',
#   'turned',
#   'keeps',
#   'feel',
#   'person',
#   'testing',
#   'symptoms',
#   'keep',
#   'someone',
#   'want',
#   'though',
#   'anyone'],
#  ['work',
#   'great',
#   'see',
#   'contact',
#   'good',
#   'get',
#   'never',
#   'safe',
#   'phone',
#   'turn',
#   'results',
#   'would',
#   'google',
#   'idea',
#   'code',
#   'download',
#   'people',
#   'test',
#   'since',
#   'bluetooth'],
#  ['something',
#   'thanks',
#   'well',
#   'much',
#   'report',
#   'love',
#   'since',
#   'alert',
#   'stars',
#   'hope',
#   'however',
#   'always',
#   'together',
#   'turn',
#   'hours',
#   'verification',
#   'stay',
#   'set',
#   'new',
#   'ago'],
#  ['got',
#   'able',
#   'try',
#   'really',
#   'makes',
#   'people',
#   'using',
#   'days',
#   'positive',
#   'every',
#   'getting',
#   'everyone',
#   'anything',
#   'sure',
#   'results',
#   'around',
#   'day',
#   'state',
#   'used',
#   'times'],
#  ['bluetooth',
#   'virus',
#   'would',
#   'exposed',
#   'privacy',
#   'said',
#   'pandemic',
#   'says',
#   'cannot',
#   'supposed',
#   'tried',
#   'covid',
#   'pin',
#   'battery',
#   'seems',
#   'installing',
#   'going',
#   'could',
#   'went',
#   'newline'],
#  ['contact',
#   'location',
#   'give',
#   'help',
#   'see',
#   'update',
#   'send',
#   'code',
#   'one',
#   'go',
#   'part',
#   'please',
#   'time',
#   'think',
#   'call',
#   'provide',
#   'work',
#   'back',
#   'get',
#   'life']]

# %%
for i in top_20_ctm:
  print(i)
# Out:
# ['use', 'get', 'time', 'easy', 'us', 'way', 'think', 'useful', 'thing', 'one', 'wrong', 'things', 'everything', 'put', 'working', 'give', 'idea', 'people', 'take', 'go']
# ['even', 'google', 'completely', 'far', 'minutes', 'start', 'finally', 'possible', 'mask', 'already', 'gets', 'county', 'glad', 'android', 'numbers', 'enter', 'government', 'least', 'developer', 'wifi']
# ['something', 'new', 'since', 'actually', 'report', 'well', 'turn', 'hope', 'thanks', 'much', 'say', 'love', 'safe', 'hours', 'alert', 'checked', 'ago', 'stars', 'cases', 'family']
# ['told', 'mind', 'apple', 'soon', 'nj', 'horrible', 'utah', 'reason', 'option', 'via', 'twice', 'screen', 'difficult', 'came', 'masks', 'matter', 'page', 'slow', 'awesome', 'hour']
# ['notifications', 'thank', 'idea', 'phone', 'tracking', 'download', 'find', 'number', 'downloaded', 'waste', 'department', 'installed', 'notification', 'stop', 'fix', 'notify', 'notified', 'found', 'available', 'wish']
# ['love', 'however', 'report', 'spread', 'received', 'alert', 'since', 'actually', 'well', 'ago', 'turn', 'today', 'week', 'verification', 'much', 'else', 'safe', 'family', 'thanks', 'say']
# ['access', 'notification', 'notify', 'needs', 'installed', 'tracking', 'alerts', 'need', 'number', 'phone', 'open', 'downloaded', 'find', 'download', 'notified', 'stop', 'save', 'thank', 'needed', 'waste']
# ['know', 'exposure', 'install', 'right', 'last', 'data', 'allow', 'setup', 'uninstall', 'date', 'asks', 'concept', 'system', 'application', 'home', 'im', 'list', 'contacts', 'process', 'social']
# ['covid', 'battery', 'going', 'tried', 'seems', 'permissions', 'saying', 'went', 'trying', 'pin', 'started', 'anonymous', 'almost', 'quarantine', 'wants', 'nobody', 'uninstalling', 'waiting', 'wanted', 'installing']
# ['safe', 'since', 'hope', 'received', 'love', 'spread', 'much', 'store', 'alert', 'new', 'turn', 'actually', 'report', 'something', 'well', 'long', 'verification', 'thanks', 'else', 'however']
# ['hour', 'apple', 'space', 'background', 'told', 'mine', 'cant', 'correctly', 'screen', 'extremely', 'informative', 'informed', 'response', 'trust', 'unfortunately', 'page', 'checks', 'saw', 'problems', 'came']
# ['easy', 'get', 'use', 'way', 'us', 'time', 'useful', 'thing', 'think', 'wrong', 'working', 'things', 'everything', 'one', 'put', 'given', 'take', 'worked', 'check', 'health']
# ['keep', 'without', 'tested', 'others', 'want', 'someone', 'still', 'test', 'nothing', 'though', 'keeps', 'first', 'another', 'useless', 'never', 'past', 'testing', 'accurate', 'anyone', 'yet']
# ['code', 'go', 'back', 'one', 'enough', 'tell', 'wrong', 'home', 'lot', 'share', 'contact', 'name', 'quick', 'show', 'system', 'order', 'data', 'job', 'give', 'leave']
# ['like', 'results', 'everyone', 'got', 'uses', 'day', 'people', 'using', 'positive', 'sure', 'able', 'getting', 'state', 'really', 'days', 'around', 'anything', 'many', 'every', 'times']
# ['good', 'make', 'also', 'help', 'update', 'excellent', 'location', 'places', 'issues', 'happy', 'helpful', 'issue', 'updated', 'added', 'provide', 'provides', 'receive', 'send', 'helping', 'deleted']
# ['could', 'tracing', 'newline', 'apps', 'gps', 'stops', 'months', 'settings', 'dont', 'uninstalled', 'weeks', 'would', 'iphone', 'downloading', 'might', 'may', 'privacy', 'says', 'month', 'took']
# ['information', 'problem', 'track', 'please', 'info', 'review', 'live', 'life', 'point', 'call', 'part', 'locations', 'enable', 'care', 'ask', 'tool', 'fact', 'service', 'text', 'local']
# ['works', 'health', 'let', 'check', 'error', 'working', 'better', 'nice', 'take', 'gives', 'worked', 'put', 'giving', 'important', 'self', 'given', 'everything', 'issue', 'change', 'helpful']
# ['useless', 'yet', 'first', 'test', 'still', 'never', 'others', 'nothing', 'tested', 'turned', 'keeps', 'feel', 'person', 'testing', 'symptoms', 'keep', 'someone', 'want', 'though', 'anyone']
# ['work', 'great', 'see', 'contact', 'good', 'get', 'never', 'safe', 'phone', 'turn', 'results', 'would', 'google', 'idea', 'code', 'download', 'people', 'test', 'since', 'bluetooth']
# ['something', 'thanks', 'well', 'much', 'report', 'love', 'since', 'alert', 'stars', 'hope', 'however', 'always', 'together', 'turn', 'hours', 'verification', 'stay', 'set', 'new', 'ago']
# ['got', 'able', 'try', 'really', 'makes', 'people', 'using', 'days', 'positive', 'every', 'getting', 'everyone', 'anything', 'sure', 'results', 'around', 'day', 'state', 'used', 'times']
# ['bluetooth', 'virus', 'would', 'exposed', 'privacy', 'said', 'pandemic', 'says', 'cannot', 'supposed', 'tried', 'covid', 'pin', 'battery', 'seems', 'installing', 'going', 'could', 'went', 'newline']
# ['contact', 'location', 'give', 'help', 'see', 'update', 'send', 'code', 'one', 'go', 'part', 'please', 'time', 'think', 'call', 'provide', 'work', 'back', 'get', 'life']

# %% [markdown]
# ### **NMF**

# %%
import numpy as np

# %%
import sklearn
import sklearn.feature_extraction
import sklearn.feature_extraction.text
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
len(preprocessed_documents)
# Out:
# 78969

# %%
tfidf_vectorizer = TfidfVectorizer(
    min_df=3,
    max_df=0.85,
    max_features=9114,
    #preprocessor=' '.join
)
tfidf = tfidf_vectorizer.fit_transform(preprocessed_documents)

# %%
import sklearn
import sklearn.decomposition
from sklearn.decomposition import NMF

# %%
nmf = NMF(
    n_components=25,
    init='nndsvd',
).fit(tfidf)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/decomposition/_nmf.py:1641: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   ConvergenceWarning,

# %%
H = nmf.components_

# %%
vocab = np.array(tfidf_vectorizer.get_feature_names())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
#all words NMF
vocab = np.array(tfidf_vectorizer.get_feature_names())
top_words = lambda t: [vocab[i] for i in np.argsort(t)[::-1]]
topics_words = ([top_words(t) for t in H])
nmf_topics = [' '.join(t) for t in topics_words]
nmf_topics = [', '.join(t) for t in topics_words]
nmf_topics
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['get, way, tested, idea, beta, code, battery, information, state, everyone, well, level, still, useless, designed, intended, integrated, got, data, keep, enough, old, go, sharing, using, year, days, could, privacy, first, notification, notifications, thank, really, installed, someone, update, please, let, auto, report, self, says, downloaded, reporting, isolate, reported, quarantine, reports, respect, much, give, newline, think, alert, exposed, turn, going, virus, seems, needs, make, sure, getting, turned, political, many, tried, try, every, back, info, far, pin, times, around, without, check, hope, helpful, error, home, find, open, result, source, went, focus, figure, fighting, finish, fight, focused, field, fi, felt, files, flu, fill, filled, finally, finding, florida, flawed, flaw, fixed, fix, five, fine, folks, freedoms, follow, fully, function, functional, functionality, functioning, functions, future, galaxy, game, garbage, gave, general, generate, gets, given, gives, giving, glad, goal, god, goes, gone, gonna, good, goodness, google, fun, full, followed, frustrating, following, food, force, forced, forcing, forever, forget, forgot, form, forward, found, four, framework, free, freedom, feels, freeze, freezes, frequently, friday, friend, friendly, friends, front, frustrated, feet, false, feeling, er, end, ended, energy, engineer, english, ensure, enter, entered, entering, entire, entirely, entry, errands, encourage, errors, especially, essential, essentially, etc, even, evening, eventually, ever, everybody, everyday, everything, encouraging, encounters, everywhere, election, eats, economy, edit, effect, effective, effectively, effectiveness, efficient, effort, efforts, either, elderly, else, encountered, elsewhere, email, emailed, emails, emergency, employee, employees, employer, en, enable, enabled, enabling, everytime, exact, feel, fan, fail, failed, failing, fails, failure, fair, faith, fake, fall, gov, families, family, fantastic, fact, faq, fast, faster, fault, favor, fear, feature, features, feb, february, federal, feedback, facts, facility, exactly, expected, example, excelente, excellent, except, excited, excuse, executed, execution, exist, existed, exists, expect, experience, facebook, experienced, experiencing, explain, explained, explains, explanation, exposing, exposure, exposures, extra, extremely, face, gotten, zip, government, keeps, internal, internet, interstate, interview, intrusive, intuitive, invasion, invasive, involved, ios, iphone, iphones, island, isnt, issue, issues, ive, jan, january, jersey, job, john, join, joke, july, jump, junk, interface, interesting, interested, initially, individual, individuals, ineffective, infect, infected, infection, inform, informative, informed, informing, ing, initial, initiative, interactions, input, inside, inslee, install, installation, installing, installs, instantly, instead, instructed, instructions, intentions, keeping, kept, governor, key, leaders, leadership, learn, least, leave, leaves, leaving, left, less, lets, letting, levels, liberty, lie, lies, life, light, like, likely, limited, line, link, links, list, listed, listen, lists, lead, laws, law, known, keys, kids, kill, killed, killing, kills, kind, kinda, knew, know, knowing, knowledge, knows, launched, kudos, la, lab, lack, lacks, language, large, last, late, later, latest, launch, indicator, indication, indicates, indicate, havent, hawaii, head, health, healthcare, healthy, hear, heard, heck, hell, help, helped, helping, helps, hey, hi, hide, high, higher, highest, highly, hipaa, hippa, history, hit, hoax, hog, hate, hard, happy, guidelines, gps, gracias, granted, graphs, grateful, great, greater, green, groceries, grocery, groups, guess, guy, happens, guys, hack, hacked, hacking, half, hand, easy, hands, hangs, happen, happened, happening, hold, honest, honestly, improve, im, imagine, immediate, immediately, immune, impact, implementation, implemented, importance, important, impossible, impressed,  ...
#  'covid, non, slow, infected, free, nj, specific, related, mi, intrusive, functional, invasive, working, response, locked, white, virginia, county, power, positive, level, world, state, wide, nation, still, enough, old, year, sure, found, focused, framework, four, folks, follow, followed, focus, forced, form, forgot, following, forget, food, force, forever, forcing, forward, zip, flu, florida, feedback, feel, feeling, feels, feet, felt, fi, field, fight, fighting, figure, files, fill, filled, finally, find, finding, fine, finish, first, freedom, fix, fixed, flaw, flawed, five, friendly, freedoms, giving, go, goal, god, goes, going, gone, gonna, good, goodness, google, got, gotten, gov, government, governor, gps, gracias, granted, graphs, grateful, great, greater, green, groceries, grocery, groups, guess, glad, gives, freeze, given, freezes, frequently, friday, friend, february, friends, front, frustrated, frustrating, full, fully, fun, function, functionality, functioning, functions, future, galaxy, game, garbage, gave, general, generate, get, gets, getting, give, federal, far, feb, enabling, encounters, encourage, encouraging, end, ended, energy, engineer, english, ensure, enter, entered, entering, entire, entirely, entry, er, errands, error, errors, especially, essential, essentially, etc, even, evening, eventually, ever, encountered, enabled, everybody, enable, easiest, easily, easy, eat, eats, economy, edit, effect, effective, effectively, effectiveness, efficient, effort, efforts, either, elderly, election, else, elsewhere, email, emailed, emails, emergency, employee, employees, employer, en, every, everyday, features, extra, face, facebook, facility, fact, facts, fail, failed, failing, fails, failure, fair, faith, fake, fall, false, families, family, fan, fantastic, faq, guy, fast, faster, fault, favor, fear, feature, extremely, exposures, everyone, exposure, everything, everytime, everywhere, exact, exactly, example, excelente, excellent, except, excited, excuse, executed, execution, exist, existed, exists, expect, expected, experience, experienced, experiencing, explain, explained, explains, explanation, exposed, exposing, guidelines, happen, guys, isnt, issue, issues, ive, jan, january, jersey, job, john, join, joke, july, jump, junk, keep, keeping, keeps, kept, key, keys, kids, kill, killed, killing, kills, kind, kinda, knew, isolate, island, knowing, iphones, inside, inslee, install, installation, installed, installing, installs, instantly, instead, instructed, instructions, integrated, intended, intentions, interactions, interested, interesting, interface, internal, internet, interstate, interview, intuitive, invasion, involved, ios, iphone, know, knowledge, initiative, levels, lie, lies, life, light, like, likely, limited, line, link, links, list, listed, listen, lists, literally, little, live, lives, living, load, loaded, loads, local, locally, locate, location, locations, liberty, letting, known, lets, knows, kudos, la, lab, lack, lacks, language, large, last, late, later, latest, launch, launched, law, laws, lead, leaders, leadership, learn, least, leave, leaves, leaving, left, less, let, input, initially, hack, hi, high, higher, highest, highly, hipaa, hippa, history, hit, hoax, hog, hold, home, honest, honestly, hope, hopeful, hopefully, hopes, hoping, horrible, hospital, hospitals, hot, hour, hours, house, household, hide, hey, hrs, helps, hacked, hacking, half, hand, hands, hangs, ease, happened, happening, happens, happy, hard, hate, havent, hawaii, head, health, healthcare, healthy, hear, heard, heck, hell, help, helped, helpful, helping, however, huge, initial, improved, improvements, inaccurate, inactive, include, included, includes, including, incorrect, increase, incredible, incredibly, indicate, indicates, indication, indicator, individual, individuals, ineffective, infect, infection, info, inform, information, informative, informed, informing, ing, improvement, improve, human, impressed, hundred, hu ...
#  'use, easy, see, well, data, designed, intended, integrated, sharing, downloaded, give, exposed, virus, sure, turned, political, helpful, used, trying, thing, nice, followed, food, following, free, freedoms, follow, force, folks, freezes, freeze, forcing, forced, framework, forever, forget, forgot, form, forward, focused, freedom, four, found, zip, focus, flu, feel, feeling, feels, feet, felt, fi, field, fight, fighting, figure, files, fill, filled, finally, find, finding, fine, finish, first, five, fix, fixed, flaw, frequently, florida, flawed, front, friday, granted, going, gone, gonna, good, goodness, google, got, gotten, gov, government, governor, gps, gracias, graphs, friend, grateful, great, greater, green, groceries, grocery, groups, guess, guidelines, guy, guys, hack, hacked, goes, god, goal, go, friendly, friends, federal, frustrated, frustrating, full, fully, fun, function, functional, functionality, functioning, functions, future, galaxy, game, garbage, gave, general, generate, get, gets, getting, given, gives, giving, glad, feedback, favor, february, entire, encounters, encourage, encouraging, end, ended, energy, engineer, english, enough, ensure, enter, entered, entering, entirely, feb, entry, er, errands, error, errors, especially, essential, essentially, etc, even, evening, eventually, ever, encountered, enabling, enabled, enable, easier, easiest, easily, eat, eats, economy, edit, effect, effective, effectively, effectiveness, efficient, effort, efforts, either, elderly, election, else, elsewhere, email, emailed, emails, emergency, employee, employees, employer, en, every, everybody, everyday, extremely, facebook, facility, fact, facts, fail, failed, failing, fails, failure, fair, faith, fake, fall, false, families, family, fan, fantastic, faq, far, fast, faster, fault, half, fear, feature, features, face, extra, everyone, exposures, everything, everytime, everywhere, exact, exactly, example, excelente, excellent, except, excited, excuse, executed, execution, exist, existed, exists, expect, expected, experience, experienced, experiencing, explain, explained, explains, explanation, exposing, exposure, hacking, happening, hand, keys, jersey, job, john, join, joke, july, jump, junk, keep, keeping, keeps, kept, key, kids, hands, kill, killed, killing, kills, kind, kinda, knew, know, knowing, knowledge, known, knows, kudos, january, jan, ive, issues, installing, installs, instantly, instead, instructed, instructions, intentions, interactions, interested, interesting, interface, internal, internet, interstate, interview, intrusive, intuitive, invasion, invasive, involved, ios, iphone, iphones, island, isnt, isolate, issue, la, lab, lack, light, likely, limited, line, link, links, list, listed, listen, lists, literally, little, live, lives, living, load, loaded, loads, local, locally, locate, location, locations, locked, locks, log, logged, logging, like, life, lacks, lies, language, large, last, late, later, latest, launch, launched, law, laws, lead, leaders, leadership, learn, least, leave, leaves, leaving, left, less, let, lets, letting, level, levels, liberty, lie, installed, installation, install, hipaa, history, hit, hoax, hog, hold, home, honest, honestly, hope, hopeful, hopefully, hopes, hoping, horrible, hospital, hospitals, hot, hour, hours, house, household, however, hrs, huge, human, hundred, hundreds, hippa, highly, hurt, highest, hangs, happen, happened, early, happens, happy, hard, hate, havent, hawaii, head, health, healthcare, healthy, hear, heard, heck, hell, help, helped, helping, helps, hey, hi, hide, high, higher, hung, husband, inslee, included, including, incorrect, increase, incredible, incredibly, indicate, indicates, indication, indicator, individual, individuals, ineffective, infect, infected, infection, info, inform, information, informative, informed, informing, ing, initial, initially, initiative, input, inside, includes, include, icon, inactive, id, idea, ideal, identifiable, identify, i ...
#  'work, state, data, well, level, install, still, useless, designed, sharing, intended, county, integrated, enough, old, go, specific, year, virginia, privacy, non, first, working, intrusive, functional, invasive, response, locked, white, day, per, says, much, think, alert, turn, tried, many, try, hope, helpful, used, useful, thing, new, received, put, cannot, makes, take, forced, felt, focused, feel, fi, feeling, forever, force, feet, folks, follow, forcing, following, feels, food, followed, find, focus, figure, finding, fine, finish, finally, forget, filled, fill, files, five, flu, fix, fighting, fight, fixed, field, flaw, flawed, florida, zip, freezes, forgot, good, gets, getting, give, given, gives, giving, glad, goal, god, goes, going, gone, gonna, goodness, generate, google, got, gotten, gov, government, governor, gps, gracias, granted, graphs, grateful, great, greater, get, general, form, friends, forward, found, four, framework, free, freedom, freedoms, freeze, federal, frequently, friday, friend, friendly, front, gave, frustrated, frustrating, full, fully, fun, function, functionality, functioning, functions, future, galaxy, game, garbage, feedback, fantastic, february, enabling, encounters, encourage, encouraging, end, ended, energy, engineer, english, ensure, enter, entered, entering, entire, entirely, entry, er, errands, error, errors, especially, essential, essentially, etc, even, evening, eventually, ever, encountered, enabled, everybody, enable, easiest, easily, easy, eat, eats, economy, edit, effect, effective, effectively, effectiveness, efficient, effort, efforts, either, elderly, election, else, elsewhere, email, emailed, emails, emergency, employee, employees, employer, en, every, everyday, feb, extra, face, facebook, facility, fact, facts, fail, failed, failing, fails, failure, fair, faith, fake, fall, false, families, family, fan, faq, far, fast, faster, fault, favor, fear, feature, features, extremely, exposures, everyone, exposure, everything, everytime, everywhere, exact, exactly, example, excelente, excellent, except, excited, excuse, executed, execution, exist, existed, exists, expect, expected, experience, experienced, experiencing, explain, explained, explains, explanation, exposed, exposing, green, happened, groceries, ios, iphones, island, isnt, isolate, issue, issues, ive, jan, january, jersey, job, john, join, joke, july, jump, junk, keep, keeping, keeps, kept, key, keys, kids, kill, killed, killing, iphone, involved, grocery, invasion, informed, informing, ing, initial, initially, initiative, input, inside, inslee, installation, installed, installing, installs, instantly, instead, instructed, instructions, intentions, interactions, interested, interesting, interface, internal, internet, interstate, interview, intuitive, kills, kind, kinda, knew, let, lets, letting, levels, liberty, lie, lies, life, light, like, likely, limited, line, link, links, list, listed, listen, lists, literally, little, live, lives, living, load, loaded, loads, less, left, leaving, last, know, knowing, knowledge, known, knows, kudos, la, lab, lack, lacks, language, large, late, leaves, later, latest, launch, launched, law, laws, lead, leaders, leadership, learn, least, leave, informative, information, inform, hour, helped, helping, helps, hey, hi, hide, high, higher, highest, highly, hipaa, hippa, history, hit, hoax, hog, hold, home, honest, honestly, hopeful, hopefully, hopes, hoping, horrible, hospital, hospitals, help, hell, heck, happen, groups, guess, guidelines, guy, guys, hack, hacked, hacking, half, hand, hands, hangs, ease, heard, happening, happens, happy, hard, hate, havent, hawaii, head, health, healthcare, healthy, hear, hot, hours, info, house, important, impossible, impressed, improve, improved, improvement, improvements, inaccurate, inactive, include, included, includes, including, incorrect, increase, incredible, incredibly, indicate, indicates, indication, indicator, individual, individuals, ineffectiv ...
#  'people, tested, idea, beta, battery, information, well, install, still, got, designed, intended, integrated, keep, enough, old, using, year, could, notification, really, please, let, much, think, exposed, alert, going, virus, turned, political, sure, tried, tracking, every, info, times, without, around, helpful, find, home, used, something, trying, result, useful, number, right, new, thing, today, wrong, forgot, form, forever, forget, force, following, forcing, food, forced, followed, fix, follow, finding, felt, fi, field, fight, fighting, figure, files, fill, filled, finally, fine, folks, finish, first, five, fixed, flaw, flawed, florida, flu, focus, focused, forward, friend, found, get, getting, give, given, gives, giving, glad, go, goal, god, goes, gone, gonna, good, goodness, google, gotten, gov, government, governor, gps, gracias, granted, graphs, grateful, great, greater, green, gets, generate, four, general, framework, free, freedom, freedoms, freeze, freezes, frequently, friday, feels, friendly, friends, front, frustrated, frustrating, full, fully, fun, function, functional, functionality, functioning, functions, future, galaxy, game, garbage, gave, feet, zip, feeling, entry, encourage, encouraging, end, ended, energy, engineer, english, ensure, enter, entered, entering, entire, entirely, er, encountered, errands, error, errors, especially, essential, essentially, etc, even, evening, eventually, ever, everybody, everyday, encounters, enabling, feel, efforts, easiest, easily, easy, eat, eats, economy, edit, effect, effective, effectively, effectiveness, efficient, effort, either, enabled, elderly, election, else, elsewhere, email, emailed, emails, emergency, employee, employees, employer, en, enable, everyone, everything, everytime, fan, facts, fail, failed, failing, fails, failure, fair, faith, fake, fall, false, families, family, fantastic, everywhere, faq, far, fast, faster, fault, favor, fear, feature, features, feb, february, federal, feedback, fact, facility, facebook, face, exact, exactly, example, excelente, excellent, except, excited, excuse, executed, execution, exist, existed, exists, expect, expected, experience, experienced, experiencing, explain, explained, explains, explanation, exposing, exposure, exposures, extra, extremely, groceries, happens, grocery, informing, iphones, island, isnt, isolate, issue, issues, ive, jan, january, jersey, job, john, join, joke, july, jump, junk, keeping, keeps, kept, key, keys, kids, kill, killed, killing, kills, iphone, ios, involved, instructed, initial, initially, initiative, input, inside, inslee, installation, installed, installing, installs, instantly, instead, instructions, invasive, intentions, interactions, interested, interesting, interface, internal, internet, interstate, interview, intrusive, intuitive, invasion, kind, kinda, knew, link, letting, level, levels, liberty, lie, lies, life, light, like, likely, limited, line, links, less, list, listed, listen, lists, literally, little, live, lives, living, load, loaded, loads, lets, left, know, late, knowing, knowledge, known, knows, kudos, la, lab, lack, lacks, language, large, last, later, leaving, latest, launch, launched, law, laws, lead, leaders, leadership, learn, least, leave, leaves, ing, informed, groups, informative, helping, helps, hey, hi, hide, high, higher, highest, highly, hipaa, hippa, history, hit, hoax, hog, hold, honest, honestly, hope, hopeful, hopefully, hopes, hoping, horrible, hospital, hospitals, hot, helped, help, hell, happened, guess, guidelines, guy, guys, hack, hacked, hacking, half, hand, hands, hangs, happen, happening, heck, ease, happy, hard, hate, havent, hawaii, head, health, healthcare, healthy, hear, heard, hour, hours, house, increase, impressed, improve, improved, improvement, improvements, inaccurate, inactive, include, included, includes, including, incorrect, incredible, important, incredibly, indicate, indicates, indication, indicator, individual, individuals, ineffecti ...
#  'great, see, state, everyone, data, level, still, useless, sharing, county, enough, old, specific, year, using, days, virginia, non, working, intrusive, functional, invasive, response, locked, white, installed, report, self, reporting, isolate, reported, quarantine, reports, respect, alert, turn, many, want, every, back, hope, anything, home, open, source, anyone, tell, received, went, stop, nice, ago, notify, notified, cannot, department, call, forcing, graphs, follow, force, forced, food, following, followed, folks, gps, fix, focused, focus, feeling, feels, feet, felt, fi, field, fight, fighting, figure, files, fill, filled, finally, find, finding, grateful, fine, finish, first, five, fixed, flaw, flawed, florida, flu, forever, freezes, forget, forgot, garbage, gave, general, generate, get, gets, getting, give, given, gives, giving, glad, gracias, go, goal, god, goes, going, gone, gonna, good, goodness, google, got, gotten, gov, government, game, galaxy, future, feedback, form, forward, found, four, framework, free, freedom, freedoms, freeze, governor, frequently, friday, granted, functions, friend, friendly, friends, front, frustrated, frustrating, full, fully, fun, function, functionality, functioning, feel, zip, federal, er, end, ended, energy, engineer, english, ensure, enter, entered, entering, entire, entirely, entry, errands, encourage, error, errors, especially, essential, essentially, etc, even, evening, eventually, ever, everybody, everyday, encouraging, encounters, everytime, election, eats, economy, edit, effect, effective, effectively, effectiveness, efficient, effort, efforts, either, elderly, else, encountered, elsewhere, email, emailed, emails, emergency, employee, employees, employer, en, enable, enabled, enabling, everything, everywhere, february, greater, fact, facts, fail, failed, failing, fails, failure, fair, faith, fake, fall, false, family, facebook, fan, fantastic, faq, far, fast, faster, fault, favor, fear, feature, features, feb, facility, face, exact, expect, exactly, example, excelente, excellent, except, excited, excuse, executed, execution, exist, existed, exists, expected, extremely, experience, experienced, experiencing, explain, explained, explains, explanation, exposed, exposing, exposure, exposures, extra, families, happen, green, invasion, ios, iphone, iphones, island, isnt, issue, issues, ive, jan, january, jersey, job, john, join, joke, july, jump, junk, keep, keeping, keeps, kept, key, keys, kids, kill, killed, involved, intuitive, information, interview, informed, informing, ing, initial, initially, initiative, input, inside, inslee, install, installation, installing, installs, instantly, instead, instructed, instructions, integrated, intended, intentions, interactions, interested, interesting, interface, internal, internet, interstate, killing, kills, kind, kinda, less, let, lets, letting, levels, liberty, lie, lies, life, light, like, likely, limited, line, link, links, list, listed, listen, lists, literally, little, live, lives, living, load, loaded, left, leaving, leaves, large, knew, know, knowing, knowledge, known, knows, kudos, la, lab, lack, lacks, language, last, leave, late, later, latest, launch, launched, law, laws, lead, leaders, leadership, learn, least, informative, inform, groceries, hell, helped, helpful, helping, helps, hey, hi, hide, high, higher, highest, highly, hipaa, hippa, history, hit, hoax, hog, hold, honest, honestly, hopeful, hopefully, hopes, hoping, horrible, hospital, hospitals, help, heck, info, heard, grocery, groups, guess, guidelines, guy, guys, hack, hacked, hacking, half, hand, hands, hangs, easy, happened, happening, happens, happy, hard, hate, havent, hawaii, head, health, healthcare, healthy, hear, hot, hour, hours, house, important, impossible, impressed, improve, improved, improvement, improvements, inaccurate, inactive, include, included, includes, including, incorrect, increase, incredible, incredibly, indicate, indicates, indication, indic ...
#  'good, still, enough, old, year, idea, everyone, well, got, designed, intended, integrated, keep, health, could, tracing, thank, day, per, report, self, reporting, isolate, reported, quarantine, reports, respect, give, going, getting, want, track, able, pin, last, number, went, spread, nice, person, notify, waste, notified, take, feel, problem, stay, accurate, daily, following, food, force, forced, grateful, forcing, forever, forget, followed, follow, folks, focused, focus, forgot, gotten, flu, florida, feels, feet, felt, fi, field, fight, fighting, figure, files, fill, filled, finally, find, finding, fine, finish, first, five, fix, fixed, form, flawed, green, greater, great, flaw, freedoms, forward, functions, galaxy, game, garbage, gave, general, generate, governor, get, gets, given, gives, giving, glad, go, goal, god, goes, government, gone, gonna, gov, goodness, google, future, functioning, found, functionality, four, framework, free, freedom, graphs, granted, gracias, freeze, freezes, frequently, friday, friend, friendly, friends, front, frustrated, frustrating, gps, full, fully, fun, function, functional, feeling, zip, feedback, encourage, end, ended, energy, engineer, english, ensure, enter, entered, entering, entire, entirely, entry, er, errands, error, errors, especially, essential, essentially, etc, even, evening, eventually, ever, every, everybody, everyday, encouraging, encounters, federal, encountered, eat, eats, economy, edit, effect, effective, effectively, effectiveness, efficient, effort, efforts, either, elderly, election, else, elsewhere, email, emailed, emails, emergency, employee, employees, employer, en, enable, enabled, enabling, everything, everytime, everywhere, exact, fact, facts, fail, failed, failing, fails, failure, fair, faith, fake, fall, false, families, family, fan, fantastic, faq, groceries, fast, faster, fault, favor, fear, feature, features, feb, february, facility, facebook, face, expect, exactly, example, excelente, excellent, except, excited, excuse, executed, execution, exist, existed, exists, expected, extremely, experience, experienced, experiencing, explain, explained, explains, explanation, exposed, exposing, exposure, exposures, extra, far, hand, grocery, involved, iphone, iphones, island, isnt, issue, issues, ive, jan, january, jersey, job, john, join, joke, july, jump, junk, keeping, keeps, kept, key, keys, kids, kill, killed, killing, kills, ios, invasive, kinda, invasion, ing, initial, initially, initiative, input, inside, inslee, install, installation, installed, installing, installs, instantly, instead, instructed, instructions, intentions, interactions, interested, interesting, interface, internal, internet, interstate, interview, intrusive, intuitive, kind, knew, groups, lets, level, levels, liberty, lie, lies, life, light, like, likely, limited, line, link, links, list, listed, listen, lists, literally, little, live, lives, living, load, loaded, loads, local, locally, letting, let, know, less, knowing, knowledge, known, knows, kudos, la, lab, lack, lacks, language, large, late, later, latest, launch, launched, law, laws, lead, leaders, leadership, learn, least, leave, leaves, leaving, left, informing, informed, informative, helpful, helps, hey, hi, hide, high, higher, highest, highly, hipaa, hippa, history, hit, hoax, hog, hold, home, honest, honestly, hope, hopeful, hopefully, hopes, hoping, horrible, hospital, hospitals, hot, helping, helped, information, help, guess, guidelines, guy, guys, hack, hacked, hacking, half, easily, hands, hangs, happen, happened, happening, happens, happy, hard, hate, havent, hawaii, head, healthcare, healthy, hear, heard, heck, hell, hour, hours, house, household, impressed, improve, improved, improvement, improvements, inaccurate, inactive, include, included, includes, including, incorrect, increase, incredible, incredibly, indicate, indicates, indication, indicator, individual, individuals, ineffective, infect, infected, infection, info, i ...
#  'positive, false, covid, way, tested, idea, beta, code, install, useless, also, keep, days, notification, really, thank, installed, please, let, report, says, self, much, reporting, isolate, reported, quarantine, reports, respect, think, alert, turn, going, many, others, every, back, info, pin, times, around, hope, something, error, home, find, used, thanks, open, trying, useful, source, number, actually, new, spread, nice, person, put, however, ago, cannot, notified, life, wrong, testing, point, death, job, access, department, may, available, set, months, weeks, worked, enter, understand, finally, filled, fill, following, food, files, finding, force, figure, fighting, fight, followed, folks, fine, follow, flaw, finish, first, focused, forced, five, focus, flu, fix, florida, fixed, flawed, zip, frequently, forcing, glad, game, garbage, gave, general, generate, get, gets, getting, give, given, gives, giving, go, future, goal, god, goes, gone, gonna, good, goodness, google, got, gotten, gov, government, galaxy, functions, forever, fi, forget, forgot, form, forward, found, four, framework, free, freedom, freedoms, freeze, freezes, friday, functioning, friend, friendly, friends, front, frustrated, frustrating, full, fully, fun, function, functional, functionality, field, fantastic, felt, example, engineer, english, enough, ensure, entered, entering, entire, entirely, entry, er, errands, errors, especially, essential, essentially, etc, even, evening, eventually, ever, everybody, everyday, everyone, everything, everytime, everywhere, exact, energy, ended, end, email, effect, effective, effectively, effectiveness, efficient, effort, efforts, either, elderly, election, else, elsewhere, emailed, encouraging, emails, emergency, employee, employees, employer, en, enable, enabled, enabling, encountered, encounters, encourage, exactly, excelente, feet, excellent, failing, fails, failure, fair, faith, fake, fall, families, family, fan, gps, faq, far, fast, faster, fault, favor, fear, feature, features, feb, february, federal, feedback, feel, feeling, feels, failed, fail, facts, experiencing, except, excited, excuse, executed, execution, exist, existed, exists, expect, expected, experience, experienced, explain, fact, explained, explains, explanation, exposed, exposing, exposure, exposures, extra, extremely, face, facebook, facility, governor, happens, gracias, granted, internet, interstate, interview, intrusive, intuitive, invasion, invasive, involved, ios, iphone, iphones, island, isnt, issue, issues, ive, jan, january, jersey, john, join, joke, july, jump, junk, keeping, keeps, internal, interface, interesting, input, infect, infected, infection, inform, information, informative, informed, informing, ing, initial, initially, initiative, inside, interested, inslee, installation, installing, installs, instantly, instead, instructed, instructions, integrated, intended, intentions, interactions, kept, key, keys, lie, learn, least, leave, leaves, leaving, left, less, lets, letting, level, levels, liberty, lies, leaders, light, like, likely, limited, line, link, links, list, listed, listen, lists, literally, leadership, lead, kids, kudos, kill, killed, killing, kills, kind, kinda, knew, know, knowing, knowledge, known, knows, la, laws, lab, lack, lacks, language, large, last, late, later, latest, launch, launched, law, ineffective, individuals, individual, hi, healthcare, healthy, hear, heard, heck, hell, help, helped, helpful, helping, helps, hey, hide, head, high, higher, highest, highly, hipaa, hippa, history, hit, hoax, hog, hold, honest, health, hawaii, hopeful, hack, graphs, grateful, great, greater, green, groceries, grocery, groups, guess, guidelines, guy, guys, hacked, havent, hacking, half, hand, hands, hangs, happen, happened, happening, economy, happy, hard, hate, honestly, hopefully, indicator, improvements, immediately, immune, impact, implementation, implemented, importance, important, impossible, impressed, improve, improved, i ...
#  'phone, see, state, still, level, got, enough, old, county, also, go, year, specific, using, virginia, non, notifications, working, intrusive, functional, invasive, response, locked, white, please, says, downloaded, much, alert, seems, sure, tried, times, something, find, number, tell, makes, verification, feel, take, life, point, testing, death, fix, uninstalled, call, minutes, past, weeks, system, week, users, issues, checked, end, files, following, flu, focus, fi, government, focused, folks, follow, followed, food, granted, felt, feet, feels, force, feeling, forced, gov, forcing, florida, flawed, flaw, finish, figure, gracias, fill, filled, finally, gps, finding, fine, first, governor, fighting, graphs, gotten, fight, five, grateful, field, fixed, forever, given, forget, game, function, gone, going, functionality, functioning, goes, functions, future, galaxy, god, garbage, gonna, goal, gave, glad, general, generate, get, giving, gives, gets, getting, fun, fully, forgot, freezes, google, give, forward, found, four, framework, free, freedom, freedoms, freeze, frequently, good, friday, friend, friendly, friends, front, frustrated, feedback, goodness, frustrating, full, form, fan, federal, entry, encounters, encourage, encouraging, ended, energy, engineer, english, ensure, enter, entered, entering, entire, entirely, er, february, errands, error, errors, especially, essential, essentially, etc, even, evening, eventually, ever, every, everybody, encountered, enabling, enabled, enable, easiest, easily, easy, eat, eats, economy, edit, effect, effective, effectively, effectiveness, efficient, effort, efforts, either, elderly, election, else, elsewhere, email, emailed, emails, emergency, employee, employees, employer, en, everyday, everyone, everything, face, facility, fact, facts, fail, failed, failing, fails, failure, fair, faith, fake, fall, false, families, family, greater, fantastic, faq, far, fast, faster, fault, favor, fear, feature, features, feb, facebook, extremely, everytime, extra, everywhere, exact, exactly, example, excelente, excellent, except, excited, excuse, executed, execution, exist, existed, exists, expect, expected, experience, experienced, experiencing, explain, explained, explains, explanation, exposed, exposing, exposure, exposures, great, zip, green, internet, interview, intuitive, invasion, involved, ios, iphone, iphones, island, isnt, isolate, issue, ive, jan, january, jersey, job, john, join, joke, july, jump, junk, keep, keeping, keeps, kept, key, interstate, internal, kids, interface, inform, information, informative, informed, informing, ing, initial, initially, initiative, input, inside, inslee, install, installation, installed, installing, installs, instantly, instead, instructed, instructions, integrated, intended, intentions, interactions, interested, interesting, keys, kill, groceries, least, leaves, leaving, left, less, let, lets, letting, levels, liberty, lie, lies, light, like, likely, limited, line, link, links, list, listed, listen, lists, literally, little, live, lives, living, leave, learn, killed, leadership, killing, kills, kind, kinda, knew, know, knowing, knowledge, known, knows, kudos, la, lab, lack, lacks, language, large, last, late, later, latest, launch, launched, law, laws, lead, leaders, info, infection, infected, heck, help, helped, helpful, helping, helps, hey, hi, hide, high, higher, highest, highly, hipaa, hippa, history, hit, hoax, hog, hold, home, honest, honestly, hope, hopeful, hopefully, hopes, hoping, hell, heard, infect, hear, grocery, groups, guess, guidelines, guy, guys, hack, hacked, hacking, half, hand, ease, hands, hangs, happen, happened, happening, happens, happy, hard, hate, havent, hawaii, head, health, healthcare, healthy, horrible, hospital, hospitals, hot, implementation, implemented, importance, important, impossible, impressed, improve, improved, improvement, improvements, inaccurate, inactive, include, included, includes, including, incorrect, increase, ...
#  'like, idea, code, state, data, install, level, useless, sharing, also, keep, county, days, installed, day, report, per, says, self, downloaded, reporting, isolate, reported, quarantine, reports, respect, much, alert, going, turn, many, want, google, every, tracking, back, apple, able, hope, error, find, home, helpful, used, open, useful, source, right, tell, new, received, went, spread, nice, put, ago, notify, however, cannot, notified, makes, testing, problem, wrong, job, may, access, fix, department, available, android, call, uninstalled, minutes, live, weeks, worked, exposures, two, daily, long, part, star, week, enter, understand, pretty, users, end, user, date, friendly, screen, already, alerts, giving, first, glad, five, go, fixed, gives, given, give, getting, gets, flaw, get, generate, finish, finding, fine, flawed, felt, fi, field, fight, gotten, got, fighting, figure, files, fill, goodness, good, filled, gonna, finally, gone, goes, god, goal, general, focus, florida, free, fun, fully, full, form, forward, found, four, frustrating, framework, freedom, flu, feet, freedoms, freeze, freezes, frequently, frustrated, friday, friend, front, function, forgot, forget, functional, gave, friends, garbage, focused, game, galaxy, folks, future, functions, functioning, follow, followed, following, food, force, forced, forcing, forever, functionality, zip, false, feels, essentially, enough, ensure, entered, entering, entire, entirely, entry, er, errands, errors, especially, essential, etc, feeling, even, evening, eventually, ever, everybody, everyday, everyone, everything, everytime, everywhere, exact, exactly, english, engineer, energy, ended, effectively, effectiveness, efficient, effort, efforts, either, elderly, election, else, elsewhere, email, emailed, emails, emergency, employee, employees, employer, en, enable, enabled, enabling, encountered, encounters, encourage, encouraging, example, excelente, excellent, failed, fails, failure, fair, faith, fake, fall, government, families, family, fan, fantastic, faq, far, fast, faster, fault, favor, fear, feature, features, feb, february, federal, feedback, feel, failing, fail, except, facts, excited, excuse, executed, execution, exist, existed, exists, expect, expected, experience, experienced, experiencing, explain, explained, explains, explanation, exposed, exposing, exposure, extra, extremely, face, facebook, facility, fact, gov, happening, governor, iphones, interface, internal, internet, interstate, interview, intrusive, intuitive, invasion, invasive, involved, ios, iphone, island, interested, isnt, issue, issues, ive, jan, january, jersey, john, join, joke, july, jump, interesting, interactions, keeping, initially, ineffective, infect, infected, infection, info, inform, information, informative, informed, informing, ing, initial, initiative, intentions, input, inside, inslee, installation, installing, installs, instantly, instead, instructed, instructions, integrated, intended, junk, keeps, individual, letting, lead, leaders, leadership, learn, least, leave, leaves, leaving, left, less, let, lets, levels, law, liberty, lie, lies, life, light, likely, limited, line, link, links, list, listed, laws, launched, kept, knowledge, key, keys, kids, kill, killed, killing, kills, kind, kinda, knew, know, knowing, known, launch, knows, kudos, la, lab, lack, lacks, language, large, last, late, later, latest, individuals, indicator, gps, hey, head, health, healthcare, healthy, hear, heard, heck, hell, help, helped, helping, helps, hi, havent, hide, high, higher, highest, highly, hipaa, hippa, history, hit, hoax, hog, hold, hawaii, hate, honestly, guy, gracias, granted, graphs, grateful, great, greater, green, groceries, grocery, groups, guess, guidelines, guys, hard, hack, hacked, hacking, half, hand, hands, hangs, happen, happened, effect, happens, happy, honest, hopeful, indication, improvement, immediate, immediately, immune, impact, implementation, implemented, importance, important, i ...
#  'results, way, tested, idea, beta, code, battery, everyone, data, got, also, sharing, using, days, could, notifications, someone, thank, really, please, report, self, downloaded, reporting, isolate, reported, quarantine, reports, respect, give, going, virus, make, better, turned, political, google, apple, far, pin, able, open, result, thanks, source, number, actually, anyone, tell, went, received, person, notify, keeps, notified, hours, verification, uses, another, access, say, past, symptoms, daily, government, pretty, share, saying, personal, places, close, ask, tool, always, fine, save, effective, several, everywhere, fully, forgot, form, enabling, forward, found, four, framework, free, freedom, freedoms, freeze, freezes, frequently, enabled, friday, friend, friendly, friends, front, frustrated, enable, frustrating, forget, encountered, forever, focused, fix, fixed, engineer, energy, flaw, ended, flawed, florida, flu, focus, folks, encounters, follow, followed, following, food, end, force, forced, encouraging, forcing, encourage, full, fun, first, gonna, elsewhere, else, glad, go, goal, god, goes, election, gone, elderly, good, function, goodness, either, efforts, gotten, effort, efficient, gov, effectiveness, governor, effectively, email, giving, gives, emailed, functional, functionality, functioning, en, functions, employer, future, galaxy, game, garbage, employees, gave, general, generate, employee, get, gets, getting, emergency, emails, given, five, english, everytime, extra, evening, explains, explanation, even, etc, exposed, essentially, exposing, exposure, exposures, essential, explain, extremely, face, facebook, facility, fact, especially, facts, fail, failed, failing, explained, experiencing, finish, excuse, exact, exactly, everything, example, everyday, excelente, excellent, everybody, except, excited, every, eventually, executed, execution, exist, existed, exists, expect, expected, experience, ever, experienced, fails, failure, fair, entered, federal, feedback, feel, feeling, feels, feet, felt, fi, field, fight, fighting, faith, figure, files, enter, ensure, fill, filled, finally, find, finding, enough, february, entering, feb, features, fake, fall, errors, false, families, error, errands, family, fan, gps, er, faq, entry, fast, entirely, faster, entire, fault, favor, fear, feature, fantastic, zip, gracias, issue, internet, interstate, interview, intrusive, intuitive, invasion, invasive, involved, ios, iphone, iphones, island, isnt, issues, granted, ive, jan, january, jersey, job, john, join, joke, july, jump, junk, keep, keeping, internal, interface, interesting, interested, infection, info, inform, information, informative, informed, informing, ing, initial, initially, initiative, input, inside, inslee, install, installation, installed, installing, installs, instantly, instead, instructed, instructions, integrated, intended, intentions, interactions, kept, key, keys, leadership, least, leave, leaves, leaving, left, less, let, lets, letting, level, levels, liberty, lie, lies, life, light, like, likely, limited, line, link, links, list, listed, listen, lists, literally, learn, leaders, kids, lead, kill, killed, killing, kills, kind, kinda, knew, know, knowing, knowledge, known, knows, kudos, la, lab, lack, lacks, language, large, last, late, later, latest, launch, launched, law, laws, infected, infect, ineffective, health, healthy, hear, heard, heck, hell, help, helped, helpful, helping, helps, hey, hi, hide, high, higher, highest, highly, hipaa, hippa, history, hit, hoax, hog, hold, home, honest, honestly, healthcare, head, hopeful, hawaii, graphs, grateful, great, greater, green, groceries, grocery, groups, guess, guidelines, guy, guys, hack, effect, hacking, half, hand, hands, hangs, happen, happened, happening, happens, happy, hard, hate, havent, hope, hopefully, individuals, immediate, immune, impact, implementation, implemented, importance, important, impossible, impressed, improve, improved, improvement,  ...
# ...
#  'contact, need, tracing, non, health, intrusive, functional, invasive, working, response, locked, specific, white, virginia, county, tested, level, beta, state, code, battery, also, could, please, report, self, reporting, isolate, reported, quarantine, reports, respect, much, think, virus, needs, turned, political, info, trying, number, anyone, stop, notify, hours, notified, another, point, say, access, though, show, glad, daily, saying, else, places, phones, always, ask, updated, several, option, little, running, dont, deleted, iphone, fact, food, fighting, forced, fi, field, fight, felt, following, forcing, force, figure, focus, followed, finally, fine, finish, first, five, fix, finding, fixed, find, filled, follow, flaw, fill, flawed, florida, flu, focused, folks, files, zip, freezes, forever, goal, garbage, gave, general, generate, get, gets, getting, give, given, gives, giving, go, god, forget, goes, going, gone, gonna, good, goodness, google, got, gotten, gov, government, governor, game, galaxy, future, functions, forgot, form, forward, found, four, framework, free, freedom, freedoms, freeze, feels, frequently, friday, friend, friendly, friends, front, frustrated, frustrating, full, fully, fun, function, functionality, functioning, feet, faq, feeling, feel, english, enough, ensure, enter, entered, entering, entire, entirely, entry, er, errands, error, errors, especially, essential, essentially, etc, even, evening, eventually, ever, every, everybody, everyday, everyone, everything, everytime, engineer, energy, ended, emailed, effect, effective, effectively, effectiveness, efficient, effort, efforts, either, elderly, election, elsewhere, email, emails, end, emergency, employee, employees, employer, en, enable, enabled, enabling, encountered, encounters, encourage, encouraging, everywhere, exact, exactly, fantastic, failed, failing, fails, failure, fair, faith, fake, fall, false, families, family, fan, gracias, facts, far, fast, faster, fault, favor, fear, feature, features, feb, february, federal, feedback, fail, facility, example, experience, excelente, excellent, except, excited, excuse, executed, execution, exist, existed, exists, expect, expected, experienced, facebook, experiencing, explain, explained, explains, explanation, exposed, exposing, exposure, exposures, extra, extremely, face, gps, hands, granted, interface, internet, interstate, interview, intuitive, invasion, involved, ios, iphones, island, isnt, issue, issues, ive, jan, january, jersey, job, john, join, joke, july, jump, junk, keep, keeping, keeps, kept, internal, interesting, graphs, interested, infected, infection, inform, information, informative, informed, informing, ing, initial, initially, initiative, input, inside, inslee, install, installation, installed, installing, installs, instantly, instead, instructed, instructions, integrated, intended, intentions, interactions, key, keys, kids, kill, least, leave, leaves, leaving, left, less, let, lets, letting, levels, liberty, lie, lies, life, light, like, likely, limited, line, link, links, list, listed, listen, lists, literally, live, learn, leadership, leaders, la, killed, killing, kills, kind, kinda, knew, know, knowing, knowledge, known, knows, kudos, lab, lead, lack, lacks, language, large, last, late, later, latest, launch, launched, law, laws, infect, ineffective, individuals, hopefully, hear, heard, heck, hell, help, helped, helpful, helping, helps, hey, hi, hide, high, higher, highest, highly, hipaa, hippa, history, hit, hoax, hog, hold, home, honest, honestly, hope, healthy, healthcare, head, hacked, grateful, great, greater, green, groceries, grocery, groups, guess, guidelines, guy, guys, hack, hacking, hawaii, half, hand, economy, hangs, happen, happened, happening, happens, happy, hard, hate, havent, hopeful, hopes, individual, hoping, immediately, immune, impact, implementation, implemented, importance, important, impossible, impressed, improve, improved, improvement, improvements, inacc ...
#  'works, help, us, see, information, state, everyone, install, data, level, got, health, county, sharing, tracing, specific, privacy, virginia, non, using, first, notifications, intrusive, working, functional, invasive, response, locked, white, someone, really, thank, update, day, auto, per, safe, downloaded, newline, make, better, seems, getting, track, tried, try, want, others, google, apple, able, far, pin, nothing, simple, times, love, without, check, last, helpful, anything, apps, thanks, result, settings, yet, actually, tell, went, nice, keeps, waste, today, said, verification, take, feel, stay, life, wish, death, store, accurate, locations, two, past, exposures, symptoms, come, finally, lot, star, issues, pretty, checked, share, cases, issue, family, close, add, tool, stopped, already, ever, states, stars, effective, message, least, near, order, excellent, range, might, within, short, awesome, maybe, reviews, later, concept, permissions, security, sense, found, shows, read, important, text, big, gets, brother, worthless, device, change, stops, sick, technology, setup, stuck, receive, samsung, drain, less, developer, tech, instead, drains, mask, super, pro, filled, fighting, fight, finish, field, finding, fine, fill, fi, figure, find, felt, files, zip, form, five, frustrated, freedoms, freeze, freezes, frequently, friday, friend, friendly, friends, front, frustrating, free, full, fully, fun, function, functionality, functioning, functions, future, galaxy, freedom, framework, fix, followed, fixed, flaw, flawed, florida, flu, focus, focused, folks, follow, following, four, food, force, forced, forcing, forever, forget, forgot, feels, forward, feet, fail, feeling, end, energy, engineer, english, enough, ensure, enter, entered, entering, entire, entirely, entry, er, errands, error, errors, especially, essential, essentially, etc, even, evening, eventually, every, everybody, everyday, ended, encouraging, everytime, encourage, edit, effect, effectively, effectiveness, efficient, effort, efforts, either, elderly, election, else, elsewhere, email, emailed, emails, emergency, employee, employees, employer, en, enable, enabled, enabling, encountered, encounters, everything, everywhere, feedback, facility, facts, garbage, failed, failing, fails, failure, fair, faith, fake, fall, false, families, fan, fantastic, faq, fast, faster, fault, favor, fear, feature, features, feb, february, federal, fact, facebook, exact, face, exactly, example, excelente, except, excited, excuse, executed, execution, exist, existed, exists, expect, expected, experience, experienced, experiencing, explain, explained, explains, explanation, exposed, exposing, exposure, extra, extremely, game, groups, gave, installs, informed, informing, ing, initial, initially, initiative, input, inside, inslee, installation, installed, installing, instantly, inform, instructed, instructions, integrated, intended, intentions, interactions, interested, interesting, interface, internal, internet, interstate, informative, info, implementation, including, importance, impossible, impressed, improve, improved, improvement, improvements, inaccurate, inactive, include, included, includes, incorrect, infection, increase, incredible, incredibly, indicate, indicates, indication, indicator, individual, individuals, ineffective, infect, infected, interview, intuitive, invasion, large, knew, know, knowing, knowledge, known, knows, kudos, la, lab, lack, lacks, language, late, involved, latest, launch, launched, law, laws, lead, leaders, leadership, learn, leave, leaves, leaving, kinda, kind, kills, killing, ios, iphone, iphones, island, isnt, isolate, ive, jan, january, jersey, job, john, join, joke, july, jump, junk, keep, keeping, kept, key, keys, kids, kill, killed, implemented, impact, general, happen, eats, guess, guidelines, guy, guys, hack, hacked, hacking, half, hand, hands, hangs, happened, groceries, happening, happens, happy, hard, hate, havent, hawaii, head, healthcare, health ...
#  'never, pandemic, code, since, data, still, useless, also, sharing, enough, old, go, year, days, notification, someone, installed, let, says, downloaded, much, think, alert, turn, needs, sure, many, tracking, every, back, info, around, love, hope, error, something, find, used, anything, home, open, trying, useful, source, actually, anyone, tell, received, stop, put, ago, cannot, makes, testing, another, may, department, available, though, call, set, uninstalled, android, minutes, show, locations, glad, weeks, worked, part, system, week, enter, understand, review, users, end, user, friendly, personal, allow, phones, negative, screen, updated, downloading, always, fine, alerts, requires, enable, mask, everything, super, place, pro, quick, made, fast, option, told, concept, lives, deleted, together, area, page, supposed, iphone, came, send, button, given, uninstall, stupid, gave, sent, telling, either, continue, took, leave, devices, everywhere, freedom, found, four, emergency, framework, free, freeze, freedoms, employee, freezes, frequently, friday, friend, emails, friends, front, emailed, frustrated, forward, employees, form, excuse, follow, encounters, encountered, followed, following, exists, enabling, food, existed, exist, force, enabled, execution, en, forced, forcing, executed, employer, forever, forget, forgot, frustrating, fully, full, excelente, exactly, except, gives, efforts, excellent, giving, effort, efficient, effectiveness, goal, email, effectively, god, goes, going, effective, gone, gonna, good, goodness, elderly, give, getting, gets, focused, fun, function, functional, functionality, elsewhere, functioning, excited, functions, future, else, galaxy, exact, game, garbage, general, generate, get, election, folks, focus, explanation, evening, etc, failing, fails, failure, essentially, fair, essential, especially, faith, fake, fall, experienced, false, families, google, family, errors, fan, fantastic, faq, far, even, eventually, er, ever, exposed, exposing, exposure, everytime, exposures, extra, extremely, explains, face, explained, facebook, explain, experiencing, facility, fact, facts, everyone, everyday, fail, everybody, failed, errands, experience, flu, fight, engineer, fighting, figure, files, expect, fill, filled, energy, finally, example, finding, encouraging, finish, first, encourage, five, fix, fixed, flaw, flawed, florida, english, field, entry, fi, expected, faster, entirely, fault, entire, favor, fear, feature, features, feb, february, federal, feedback, feel, feeling, feels, entering, feet, felt, entered, ensure, ended, zip, got, interview, instructed, instructions, integrated, intended, intentions, interactions, interested, interesting, interface, internal, internet, interstate, intrusive, instantly, intuitive, invasion, invasive, involved, ios, iphones, island, isnt, isolate, issue, issues, ive, instead, installs, january, inform, incredible, incredibly, indicate, indicates, indication, indicator, individual, individuals, ineffective, infect, infected, infection, information, installing, informative, informed, informing, ing, initial, initially, initiative, input, inside, inslee, install, installation, jan, jersey, gotten, leadership, language, large, last, late, later, latest, launch, launched, law, laws, lead, leaders, learn, lack, least, leaves, leaving, left, less, lets, letting, level, levels, liberty, lie, lies, lacks, lab, job, kids, john, join, joke, july, jump, junk, keep, keeping, keeps, kept, key, keys, kill, la, killed, killing, kills, kind, kinda, knew, know, knowing, knowledge, known, knows, kudos, increase, incorrect, including, help, hard, hate, havent, hawaii, head, health, healthcare, healthy, hear, heard, heck, hell, helped, happens, helpful, helping, helps, hey, hi, hide, high, higher, highest, highly, hipaa, hippa, happy, happening, includes, grocery, gov, government, governor, gps, gracias, granted, graphs, grateful, great, greater, green, groceries, groups, happened, guess, guid ...

# %%
#top 20 NMF
num_words = 20
top_words = lambda t: [vocab[i] for i in np.argsort(t)[:-num_words-1:-1]]
topics_words = ([top_words(t) for t in H])
nmf_20 = [' '.join(t) for t in topics_words]
nmf_20 = [', '.join(t) for t in topics_words]
nmf_20
# Out:
# ['get, way, tested, idea, beta, code, battery, information, state, everyone, well, level, still, useless, designed, intended, integrated, got, data, keep',
#  'covid, non, slow, infected, free, nj, specific, related, mi, intrusive, functional, invasive, working, response, locked, white, virginia, county, power, positive',
#  'use, easy, see, well, data, designed, intended, integrated, sharing, downloaded, give, exposed, virus, sure, turned, political, helpful, used, trying, thing',
#  'work, state, data, well, level, install, still, useless, designed, sharing, intended, county, integrated, enough, old, go, specific, year, virginia, privacy',
#  'people, tested, idea, beta, battery, information, well, install, still, got, designed, intended, integrated, keep, enough, old, using, year, could, notification',
#  'great, see, state, everyone, data, level, still, useless, sharing, county, enough, old, specific, year, using, days, virginia, non, working, intrusive',
#  'good, still, enough, old, year, idea, everyone, well, got, designed, intended, integrated, keep, health, could, tracing, thank, day, per, report',
#  'positive, false, covid, way, tested, idea, beta, code, install, useless, also, keep, days, notification, really, thank, installed, please, let, report',
#  'phone, see, state, still, level, got, enough, old, county, also, go, year, specific, using, virginia, non, notifications, working, intrusive, functional',
#  'like, idea, code, state, data, install, level, useless, sharing, also, keep, county, days, installed, day, report, per, says, self, downloaded',
#  'results, way, tested, idea, beta, code, battery, everyone, data, got, also, sharing, using, days, could, notifications, someone, thank, really, please',
#  'would, way, tested, idea, beta, code, battery, keep, also, could, notification, help, really, thank, us, installed, let, please, give, exposed',
#  'time, real, full, tested, beta, information, everyone, since, install, got, still, useless, enough, old, go, year, using, privacy, first, someone',
#  'know, way, tested, idea, beta, battery, well, got, designed, intended, integrated, keep, go, using, could, notification, notifications, really, installed, please',
#  'download, way, tested, idea, beta, code, battery, everyone, got, useless, also, keep, days, could, really, thank, someone, installed, please, report',
#  'easy, use, way, idea, code, information, state, level, got, useless, also, county, days, notification, thank, please, says, report, self, much',
#  'even, see, information, got, health, go, tracing, using, privacy, first, notifications, someone, thank, installed, update, auto, safe, give, newline, make',
#  'test, see, since, data, install, well, still, sharing, designed, intended, integrated, enough, old, keep, go, year, notification, really, safe, working',
#  'one, idea, code, information, well, useless, designed, intended, integrated, go, days, notification, installed, let, says, much, think, alert, turn, going',
#  'exposure, battery, see, well, data, designed, got, intended, integrated, sharing, using, could, notification, really, thank, please, let, report, self, reporting',
#  'location, battery, state, everyone, since, well, install, level, data, designed, intended, integrated, county, health, keep, sharing, go, specific, virginia, notification',
#  'bluetooth, based, app, science, helps, trash, well, designed, intended, useless, integrated, using, days, help, notification, us, let, says, much, alert',
#  'contact, need, tracing, non, health, intrusive, functional, invasive, working, response, locked, specific, white, virginia, county, tested, level, beta, state, code',
#  'works, help, us, see, information, state, everyone, install, data, level, got, health, county, sharing, tracing, specific, privacy, virginia, non, using',
#  'never, pandemic, code, since, data, still, useless, also, sharing, enough, old, go, year, days, notification, someone, installed, let, says, downloaded']

# %%
#postprocessing for coherence score
nmf_20_list = []
for i in range(len(nmf_20)):
  nmf_20_list.append(nmf_20[i].split(', '))

nmf_all_list = []
for i in range(len(nmf_topics)):
  nmf_all_list.append(nmf_topics[i].split(', '))
print(nmf_20_list)
print(nmf_all_list)
# Out:
# [['get', 'way', 'tested', 'idea', 'beta', 'code', 'battery', 'information', 'state', 'everyone', 'well', 'level', 'still', 'useless', 'designed', 'intended', 'integrated', 'got', 'data', 'keep'], ['covid', 'non', 'slow', 'infected', 'free', 'nj', 'specific', 'related', 'mi', 'intrusive', 'functional', 'invasive', 'working', 'response', 'locked', 'white', 'virginia', 'county', 'power', 'positive'], ['use', 'easy', 'see', 'well', 'data', 'designed', 'intended', 'integrated', 'sharing', 'downloaded', 'give', 'exposed', 'virus', 'sure', 'turned', 'political', 'helpful', 'used', 'trying', 'thing'], ['work', 'state', 'data', 'well', 'level', 'install', 'still', 'useless', 'designed', 'sharing', 'intended', 'county', 'integrated', 'enough', 'old', 'go', 'specific', 'year', 'virginia', 'privacy'], ['people', 'tested', 'idea', 'beta', 'battery', 'information', 'well', 'install', 'still', 'got', 'designed', 'intended', 'integrated', 'keep', 'enough', 'old', 'using', 'year', 'could', 'notification'], ['great', 'see', 'state', 'everyone', 'data', 'level', 'still', 'useless', 'sharing', 'county', 'enough', 'old', 'specific', 'year', 'using', 'days', 'virginia', 'non', 'working', 'intrusive'], ['good', 'still', 'enough', 'old', 'year', 'idea', 'everyone', 'well', 'got', 'designed', 'intended', 'integrated', 'keep', 'health', 'could', 'tracing', 'thank', 'day', 'per', 'report'], ['positive', 'false', 'covid', 'way', 'tested', 'idea', 'beta', 'code', 'install', 'useless', 'also', 'keep', 'days', 'notification', 'really', 'thank', 'installed', 'please', 'let', 'report'], ['phone', 'see', 'state', 'still', 'level', 'got', 'enough', 'old', 'county', 'also', 'go', 'year', 'specific', 'using', 'virginia', 'non', 'notifications', 'working', 'intrusive', 'functional'], ['like', 'idea', 'code', 'state', 'data', 'install', 'level', 'useless', 'sharing', 'also', 'keep', 'county', 'days', 'installed', 'day', 'report', 'per', 'says', 'self', 'downloaded'], ['results', 'way', 'tested', 'idea', 'beta', 'code', 'battery', 'everyone', 'data', 'got', 'also', 'sharing', 'using', 'days', 'could', 'notifications', 'someone', 'thank', 'really', 'please'], ['would', 'way', 'tested', 'idea', 'beta', 'code', 'battery', 'keep', 'also', 'could', 'notification', 'help', 'really', 'thank', 'us', 'installed', 'let', 'please', 'give', 'exposed'], ['time', 'real', 'full', 'tested', 'beta', 'information', 'everyone', 'since', 'install', 'got', 'still', 'useless', 'enough', 'old', 'go', 'year', 'using', 'privacy', 'first', 'someone'], ['know', 'way', 'tested', 'idea', 'beta', 'battery', 'well', 'got', 'designed', 'intended', 'integrated', 'keep', 'go', 'using', 'could', 'notification', 'notifications', 'really', 'installed', 'please'], ['download', 'way', 'tested', 'idea', 'beta', 'code', 'battery', 'everyone', 'got', 'useless', 'also', 'keep', 'days', 'could', 'really', 'thank', 'someone', 'installed', 'please', 'report'], ['easy', 'use', 'way', 'idea', 'code', 'information', 'state', 'level', 'got', 'useless', 'also', 'county', 'days', 'notification', 'thank', 'please', 'says', 'report', 'self', 'much'], ['even', 'see', 'information', 'got', 'health', 'go', 'tracing', 'using', 'privacy', 'first', 'notifications', 'someone', 'thank', 'installed', 'update', 'auto', 'safe', 'give', 'newline', 'make'], ['test', 'see', 'since', 'data', 'install', 'well', 'still', 'sharing', 'designed', 'intended', 'integrated', 'enough', 'old', 'keep', 'go', 'year', 'notification', 'really', 'safe', 'working'], ['one', 'idea', 'code', 'information', 'well', 'useless', 'designed', 'intended', 'integrated', 'go', 'days', 'notification', 'installed', 'let', 'says', 'much', 'think', 'alert', 'turn', 'going'], ['exposure', 'battery', 'see', 'well', 'data', 'designed', 'got', 'intended', 'integrated', 'sharing', 'using', 'could', 'notification', 'really', 'thank', 'please', 'let', 'report', 'self', 'reporting'], ['location', 'battery', 'state', 'everyone', 'since', 'well', 'install', 'level', 'data', ...
# [['get', 'way', 'tested', 'idea', 'beta', 'code', 'battery', 'information', 'state', 'everyone', 'well', 'level', 'still', 'useless', 'designed', 'intended', 'integrated', 'got', 'data', 'keep', 'enough', 'old', 'go', 'sharing', 'using', 'year', 'days', 'could', 'privacy', 'first', 'notification', 'notifications', 'thank', 'really', 'installed', 'someone', 'update', 'please', 'let', 'auto', 'report', 'self', 'says', 'downloaded', 'reporting', 'isolate', 'reported', 'quarantine', 'reports', 'respect', 'much', 'give', 'newline', 'think', 'alert', 'exposed', 'turn', 'going', 'virus', 'seems', 'needs', 'make', 'sure', 'getting', 'turned', 'political', 'many', 'tried', 'try', 'every', 'back', 'info', 'far', 'pin', 'times', 'around', 'without', 'check', 'hope', 'helpful', 'error', 'home', 'find', 'open', 'result', 'source', 'went', 'focus', 'figure', 'fighting', 'finish', 'fight', 'focused', 'field', 'fi', 'felt', 'files', 'flu', 'fill', 'filled', 'finally', 'finding', 'florida', 'flawed', 'flaw', 'fixed', 'fix', 'five', 'fine', 'folks', 'freedoms', 'follow', 'fully', 'function', 'functional', 'functionality', 'functioning', 'functions', 'future', 'galaxy', 'game', 'garbage', 'gave', 'general', 'generate', 'gets', 'given', 'gives', 'giving', 'glad', 'goal', 'god', 'goes', 'gone', 'gonna', 'good', 'goodness', 'google', 'fun', 'full', 'followed', 'frustrating', 'following', 'food', 'force', 'forced', 'forcing', 'forever', 'forget', 'forgot', 'form', 'forward', 'found', 'four', 'framework', 'free', 'freedom', 'feels', 'freeze', 'freezes', 'frequently', 'friday', 'friend', 'friendly', 'friends', 'front', 'frustrated', 'feet', 'false', 'feeling', 'er', 'end', 'ended', 'energy', 'engineer', 'english', 'ensure', 'enter', 'entered', 'entering', 'entire', 'entirely', 'entry', 'errands', 'encourage', 'errors', 'especially', 'essential', 'essentially', 'etc', 'even', 'evening', 'eventually', 'ever', 'everybody', 'everyday', 'everything', 'encouraging', 'encounters', 'everywhere', 'election', 'eats', 'economy', 'edit', 'effect', 'effective', 'effectively', 'effectiveness', 'efficient', 'effort', 'efforts', 'either', 'elderly', 'else', 'encountered', 'elsewhere', 'email', 'emailed', 'emails', 'emergency', 'employee', 'employees', 'employer', 'en', 'enable', 'enabled', 'enabling', 'everytime', 'exact', 'feel', 'fan', 'fail', 'failed', 'failing', 'fails', 'failure', 'fair', 'faith', 'fake', 'fall', 'gov', 'families', 'family', 'fantastic', 'fact', 'faq', 'fast', 'faster', 'fault', 'favor', 'fear', 'feature', 'features', 'feb', 'february', 'federal', 'feedback', 'facts', 'facility', 'exactly', 'expected', 'example', 'excelente', 'excellent', 'except', 'excited', 'excuse', 'executed', 'execution', 'exist', 'existed', 'exists', 'expect', 'experience', 'facebook', 'experienced', 'experiencing', 'explain', 'explained', 'explains', 'explanation', 'exposing', 'exposure', 'exposures', 'extra', 'extremely', 'face', 'gotten', 'zip', 'government', 'keeps', 'internal', 'internet', 'interstate', 'interview', 'intrusive', 'intuitive', 'invasion', 'invasive', 'involved', 'ios', 'iphone', 'iphones', 'island', 'isnt', 'issue', 'issues', 'ive', 'jan', 'january', 'jersey', 'job', 'john', 'join', 'joke', 'july', 'jump', 'junk', 'interface', 'interesting', 'interested', 'initially', 'individual', 'individuals', 'ineffective', 'infect', 'infected', 'infection', 'inform', 'informative', 'informed', 'informing', 'ing', 'initial', 'initiative', 'interactions', 'input', 'inside', 'inslee', 'install', 'installation', 'installing', 'installs', 'instantly', 'instead', 'instructed', 'instructions', 'intentions', 'keeping', 'kept', 'governor', 'key', 'leaders', 'leadership', 'learn', 'least', 'leave', 'leaves', 'leaving', 'left', 'less', 'lets', 'letting', 'levels', 'liberty', 'lie', 'lies', 'life', 'light', 'like', 'likely', 'limited', 'line', 'link', 'links', 'list', 'listed', 'listen', 'lists', 'lead', 'laws', 'law', 'known', 'keys', 'kids', 'kill', 'killed', 'killing', 'kil ...

# %% [markdown]
# ### **Coherence** **Scores**

# %%
data2 = pd.read_csv('sukanya_final_csv.csv')
data2 = data2['message']
data2
# Out:
# 0       Currently cannot get the app to work. Installe...
# 1       I thoroughly appreciate this app. I have a Sam...
# 2       All the app does is share anon covid test resu...
# 3       The app seemed to just sit idle till today. To...
# 4       Thank you for trying to keep us updated. The a...
#                               ...
# 7617    My wife and I both use this app. We both got C...
# 7618    This app does not work. I was with my friend f...
# 7619    Been trying to do my part and report my positi...
# 7620    What?s the point of having the app if it doesn...
# 7621    Well I believe this app was designed with good...
# Name: message, Length: 7622, dtype: object

# %%
overall = []
for i in range(len(data2)):
  overall.append(data2[i].split())

# %%
overall

# %%
from gensim.test.utils import common_corpus, common_dictionary
from gensim.models.coherencemodel import CoherenceModel
from gensim.models.ldamodel import LdaModel
from gensim.corpora import Dictionary
from numpy.core.numeric import array_equal

# %% [markdown]
# Coherence Scores for Top 20 words for LDA for 25 topics

# %%
lda_20 = pd.read_csv('top_20_lda.csv')
lda_20 = lda_20['termy']
lda_20
# Out:
# 0     get, error, when, up, screen, update, page, en...
# 1     on, bluetooth, location, off, turn, gps, which...
# 2     people, more, be, will, if, use, great, only, ...
# 3     we, help, can, safe, us, keep, our, will, spre...
# 4     you, if, are, your, know, or, what, can, just,...
# 5     as, no, an, there, well, out, way, find, pleas...
# 6     be, would, but, like, could, symptoms, better,...
# 7     contact, <newline>, tracing, google, health, a...
# 8     about, cases, how, information, county, users,...
# 9     positive, have, been, with, who, tested, peopl...
# 10    exposure, since, last, been, now, update, days...
# 11    not, it's, does, do, what, work, know, i'm, or...
# 12    at, location, been, locations, places, minutes...
# 13    my, results, get, test, me, can't, am, see, ab...
# 14    code, positive, test, pin, get, report, verifi...
# 15    me, notifications, try, turn, something, again...
# 16    was, had, we, were, out, said, days, after, to...
# 17    my, phone, on, battery, had, installed, issues...
# 18    your, location, data, any, does, or, privacy, ...
# 19    good, great, so, idea, far, it's, like, love, ...
# 20    covid, virus, its, new, state, big, government...
# 21    download, at, time, doesn't, all, work, waste,...
# 22    easy, very, use, simple, install, helpful, wel...
# 23    are, people, about, i'm, out, who, mask, those...
# 24    in, should, other, all, only, state, has, from...
# Name: termy, dtype: object

# %%
lda_20_topics = []
for i in range(len(lda_20)):
  lda_20_topics.append(lda_20[i].split(', '))

lda_20_topics

# %%
topics = lda_20_topics

texts = [preprocessed_documents]

dictionary = Dictionary(texts)
corpus = [dictionary.doc2bow(i) for i in overall]
cm1 = CoherenceModel(topics=topics,corpus = corpus,dictionary = dictionary, coherence='u_mass')
coherence1 = cm1.get_coherence()
print("u_mass:",coherence1)
cm2 = CoherenceModel(topics=topics,texts = texts,dictionary = dictionary, coherence='c_v')
coherence2 = cm2.get_coherence()
print('c_v:',coherence2)
cm3 = CoherenceModel(topics=topics,texts = texts,dictionary = dictionary, coherence='c_uci')
coherence3 = cm3.get_coherence()
print('c_uci:',coherence3)
cm4 = CoherenceModel(topics=topics,texts = texts,dictionary = dictionary, coherence='c_npmi')
coherence4 = cm4.get_coherence()
print('c_npmi:',coherence4)
# Out:
# u_mass: -5.5762587560959
# c_v: 0.4199408850173454
# c_uci: -0.19355815180898894
# c_npmi: 0.031995084831385856

# %% [markdown]
# Coherence Scores for all top words for LDA for 25

# %%
lda_all = pd.read_csv('all_topics_covid.csv')
lda_all = lda_all['termy']
lda_all_topics = []
for i in range(len(lda_all)):
  lda_all_topics.append(lda_all[i].split(', '))

lda_all_topics

# %%
topics = lda_all_topics

texts = [preprocessed_documents]

dictionary = Dictionary(texts)
corpus = [dictionary.doc2bow(i) for i in overall]
cm1 = CoherenceModel(topics=topics,corpus = corpus,dictionary = dictionary, coherence='u_mass')
coherence1 = cm1.get_coherence()
print("u_mass:",coherence1)
cm2 = CoherenceModel(topics=topics,texts = texts,dictionary = dictionary, coherence='c_v')
coherence2 = cm2.get_coherence()
print('c_v:',coherence2)
cm3 = CoherenceModel(topics=topics,texts = texts,dictionary = dictionary, coherence='c_uci')
coherence3 = cm3.get_coherence()
print('c_uci:',coherence3)
cm4 = CoherenceModel(topics=topics,texts = texts,dictionary = dictionary, coherence='c_npmi')
coherence4 = cm4.get_coherence()
print('c_npmi:',coherence4)
# Out:
# u_mass: -6.518233247452165
# c_v: 0.374612120932157
# c_uci: -0.9500200980942881
# c_npmi: -0.0009012527528714959

# %% [markdown]
# Coherence Scores for top 20 words for CTM for 25 topics

# %%
topics = top_20_ctm
texts = [preprocessed_documents]

dictionary = Dictionary(texts)
corpus = [dictionary.doc2bow(i) for i in overall]
cm1 = CoherenceModel(topics=topics,corpus = corpus,dictionary = dictionary, coherence='u_mass')
coherence1 = cm1.get_coherence()
print("u_mass:",coherence1)
cm2 = CoherenceModel(topics=topics,texts = texts,dictionary = dictionary, coherence='c_v')
coherence2 = cm2.get_coherence()
print('c_v:',coherence2)
cm3 = CoherenceModel(topics=topics,texts = texts,dictionary = dictionary, coherence='c_uci')
coherence3 = cm3.get_coherence()
print('c_uci:',coherence3)
cm4 = CoherenceModel(topics=topics,texts = texts,dictionary = dictionary, coherence='c_npmi')
coherence4 = cm4.get_coherence()
print('c_npmi:',coherence4)
# Out:
# u_mass: -7.8961796586606825
# c_v: 0.20486189909717775
# c_uci: -2.4325133435890525
# c_npmi: -0.09764744956025172

# %% [markdown]
# Coherence Scores for all top words for CTM for 25 topics

# %%
topics = all_ctm
texts = [preprocessed_documents]

dictionary = Dictionary(texts)
corpus = [dictionary.doc2bow(i) for i in overall]
cm1 = CoherenceModel(topics=topics,corpus = corpus,dictionary = dictionary, coherence='u_mass')
coherence1 = cm1.get_coherence()
print("u_mass:",coherence1)
cm2 = CoherenceModel(topics=topics,texts = texts,dictionary = dictionary, coherence='c_v')
coherence2 = cm2.get_coherence()
print('c_v:',coherence2)
cm3 = CoherenceModel(topics=topics,texts = texts,dictionary = dictionary, coherence='c_uci')
coherence3 = cm3.get_coherence()
print('c_uci:',coherence3)
cm4 = CoherenceModel(topics=topics,texts = texts,dictionary = dictionary, coherence='c_npmi')
coherence4 = cm4.get_coherence()
print('c_npmi:',coherence4)
# Out:
# u_mass: -7.8961796586606825
# c_v: 0.20486189909717775
# c_uci: -2.4325133435890525
# c_npmi: -0.09764744956025172

# %% [markdown]
# Coherence Scores for top 20 words for NMF

# %%
topics = nmf_20_list
texts = [preprocessed_documents]

dictionary = Dictionary(texts)
corpus = [dictionary.doc2bow(i) for i in overall]
cm1 = CoherenceModel(topics=topics,corpus = corpus,dictionary = dictionary, coherence='u_mass')
coherence1 = cm1.get_coherence()
print("u_mass:",coherence1)
cm2 = CoherenceModel(topics=topics,texts = texts,dictionary = dictionary, coherence='c_v')
coherence2 = cm2.get_coherence()
print('c_v:',coherence2)
cm3 = CoherenceModel(topics=topics,texts = texts,dictionary = dictionary, coherence='c_uci')
coherence3 = cm3.get_coherence()
print('c_uci:',coherence3)
cm4 = CoherenceModel(topics=topics,texts = texts,dictionary = dictionary, coherence='c_npmi')
coherence4 = cm4.get_coherence()
print('c_npmi:',coherence4)
# Out:
# u_mass: -8.543957168828163
# c_v: 0.23162437985959322
# c_uci: -3.434846070441137
# c_npmi: -0.12887877264186487

# %% [markdown]
# Coherence Scores for all top words for NMF

# %%
topics = nmf_all_list
texts = [preprocessed_documents]

dictionary = Dictionary(texts)
corpus = [dictionary.doc2bow(i) for i in overall]
cm1 = CoherenceModel(topics=topics,corpus = corpus,dictionary = dictionary, coherence='u_mass')
coherence1 = cm1.get_coherence()
print("u_mass:",coherence1)
cm2 = CoherenceModel(topics=topics,texts = texts,dictionary = dictionary, coherence='c_v')
coherence2 = cm2.get_coherence()
print('c_v:',coherence2)
cm3 = CoherenceModel(topics=topics,texts = texts,dictionary = dictionary, coherence='c_uci')
coherence3 = cm3.get_coherence()
print('c_uci:',coherence3)
cm4 = CoherenceModel(topics=topics,texts = texts,dictionary = dictionary, coherence='c_npmi')
coherence4 = cm4.get_coherence()
print('c_npmi:',coherence4)
# Out:
# u_mass: -8.543957168828163
# c_v: 0.23162437985959322
# c_uci: -3.434846070441137
# c_npmi: -0.12887877264186487
